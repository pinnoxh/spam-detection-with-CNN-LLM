# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import time

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import matthews_corrcoef
from transformers import get_linear_schedule_with_warmup

import torch
import torch.nn as nn
import torch.optim as optim
# Out:
# 2024-12-05 08:29:14.712347: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-12-05 08:29:14.739905: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-12-05 08:29:14.746395: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-05 08:29:14.772562: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-12-05 08:29:16.156638: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
df = pd.read_excel('/home/basilmusyaffa19/Skripsi Basil/Dataset/FIX/clean_SMS_22112024.xlsx', engine='openpyxl')
df
# Out:
#                                                    teks  label
# 0     promo beli paket flash mulai aplikasi my telko...      1
# 1     gb hari rp ribu spesial buat kamu pilih aktif ...      1
# 2     plg hormat sisa kuota flash download aplikasi ...      1
# 3     mohon hormat sisa kuota flash download aplikas...      1
# 4     hari rp ribu khusus buat kamu pilih aktif seka...      1
# ...                                                 ...    ...
# 1138             yooo sama sama aku umum kelompok kelas      0
# 1139         pernah tulis cadar belum pikir warna jeans      0
# 1140                                       bu mau kirim      0
# 1141                  berangkat pagi mau tunai transfer      0
# 1142                         berapa nomor bri atas nama      0
#
# [1143 rows x 2 columns]

# %%
print("Jumlah data sebelum:", len(df))

# Menghapus data kosong
df = df.replace('', np.nan).dropna()
# Hapus NaN
df = df.dropna(subset=['teks'])
# Menghapus nilai float
df = df[~df['teks'].apply(lambda x: isinstance(x, float))]
# Menghapus semua baris yang duplikat
df = df.drop_duplicates(subset=['teks'], keep='first')

print("Jumlah data setelah:", len(df))
# Out:
# Jumlah data sebelum: 1143
# Jumlah data setelah: 1138

# %%
label = df['label'].value_counts()
print(label)
# Out:
# label
# 1    571
# 0    567
# Name: count, dtype: int64

# %%
import pickle

def padding_texts(df):
    with open('/home/basilmusyaffa19/Skripsi Basil/Embedding Matrix/Dataset Indo/indo_keras_tokenizer.pickle', 'rb') as handle:
        keras_tokenizer = pickle.load(handle)

    sequences = keras_tokenizer.texts_to_sequences(df['teks'])
    max_length = max(len(seq) for seq in sequences)
    padded_sequences = pad_sequences(sequences, maxlen=max_length)
    vocab_size = len(keras_tokenizer.word_index) + 1
    
    return padded_sequences, vocab_size

# %%
def split_data(padded_sequences, labels, test_size, val_size, random_state=42):
    X_train, X_temp, y_train, y_temp = train_test_split(
        padded_sequences,
        labels,
        test_size=test_size,
        stratify=labels,
        random_state=random_state,
    )

    X_test, X_val, y_test, y_val = train_test_split(
        X_temp,
        y_temp,
        test_size=val_size,
        stratify=y_temp,
        random_state=random_state,
    )
    
    print(f'X_train Shape: {X_train.shape}')
    print(f'X_val Shape: {X_val.shape}')
    print(f'X_test Shape: {X_test.shape}')
    print('')
    
    print(f'y_train Class: {y_train.nunique()}')
    print(f'y_val Class: {y_val.nunique()}')
    print(f'y_test Class: {y_test.nunique()}')
    print('')
    
    return X_train, X_val, X_test, y_train, y_val, y_test

# %%
def create_data_loaders(X_train, X_val, X_test, y_train, y_val, y_test, batch_size):
    y_train = torch.tensor(y_train.values, dtype=torch.float32)
    y_val = torch.tensor(y_val.values, dtype=torch.float32)
    y_test = torch.tensor(y_test.values, dtype=torch.float32)

    X_train = torch.tensor(X_train, dtype=torch.int64)
    X_val = torch.tensor(X_val, dtype=torch.int64)
    X_test = torch.tensor(X_test, dtype=torch.int64)

    train_dataset = TensorDataset(X_train, y_train)
    val_dataset = TensorDataset(X_val, y_val)
    test_dataset = TensorDataset(X_test, y_test)

    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
    
    return train_loader, val_loader, test_loader

# %%
def prepare_data_loader(df, test_size, val_size, batch_size, random_state=42):
    padded_sequences, vocab_size = padding_texts(df)
    X_train, X_val, X_test, y_train, y_val, y_test = split_data(padded_sequences, df['label'], test_size, val_size, random_state)
    train_loader, val_loader, test_loader = create_data_loaders(X_train, X_val, X_test, y_train, y_val, y_test, batch_size=batch_size)
    
    return train_loader, val_loader, test_loader, vocab_size

# %%
class CNNModel(nn.Module):
    def __init__(self, embedding_matrix, embedding_dim, kernel_size, output_dim=1):
        super(CNNModel, self).__init__()
        
        # Embedding layer dengan Layer Normalization
        self.embedding = nn.Embedding.from_pretrained(embedding_matrix, freeze=True, padding_idx=0)
        self.layer_norm = nn.LayerNorm(embedding_dim)
        
        # Conv1 block dengan Batch Normalization
        self.conv1 = nn.Conv1d(in_channels=embedding_dim, out_channels=128, kernel_size=kernel_size)
        self.bn1 = nn.BatchNorm1d(128)
        
        self.maxpool = nn.MaxPool1d(kernel_size=kernel_size)
        self.dropout = nn.Dropout(p=0.2)
        
        # Conv2 block dengan Batch Normalization
        self.conv2 = nn.Conv1d(in_channels=128, out_channels=64, kernel_size=kernel_size)
        self.bn2 = nn.BatchNorm1d(64)
        
        self.global_maxpool = nn.AdaptiveMaxPool1d(1)
        
        # Fully connected layers
        self.fc1 = nn.Linear(64, 32)
        self.fc2 = nn.Linear(32, output_dim)
        self.relu = nn.ReLU()

    def forward(self, x):
        # Embedding layer dengan Layer Normalization
        x = self.embedding(x)
        x = self.layer_norm(x)
        x = x.permute(0, 2, 1)  # (batch_size, embedding_dim, sequence_length)
        
        # Conv1 block
        x = self.conv1(x)
        x = self.bn1(x)
        x = self.relu(x)
        x = self.maxpool(x)
        x = self.dropout(x)
        
        # Conv2 block
        x = self.conv2(x)
        x = self.bn2(x)
        x = self.relu(x)
        
        # Global pooling
        x = self.global_maxpool(x).squeeze(-1)
        x = self.dropout(x)
        
        # Fully connected layers
        x = self.relu(self.fc1(x))
        x = self.dropout(x)
        x = torch.sigmoid(self.fc2(x))
        
        return x.squeeze(-1)

# %%
class EarlyStopping:
    def __init__(self, patience, min_delta):
        self.patience = patience
        self.min_delta = min_delta
        self.counter = 0
        self.best_loss = None
        self.early_stop = False

    def __call__(self, val_loss):
        if self.best_loss is None:
            self.best_loss = val_loss
        elif val_loss < self.best_loss - self.min_delta: # Jika ada improvement
            self.best_loss = val_loss
            self.counter = 0
        else:  # Jika tidak ada improvement
            self.counter += 1
            if self.counter >= self.patience:
                self.early_stop = True

# %%
def prepare_embedding_matrix(model):
    paths = {
        'gpt2': '/home/basilmusyaffa19/Skripsi Basil/Embedding Matrix/Dataset Indo/Hasil Embedding/21 Nov/embedding_matrix_gpt2_1024D_21112024.npy',
        'llama2': '/home/basilmusyaffa19/Skripsi Basil/Embedding Matrix/Dataset Indo/Hasil Embedding/21 Nov/embedding_matrix_llama2_4096D_21112024.npy',
        'XLM-R': '/home/basilmusyaffa19/Skripsi Basil/Embedding Matrix/Dataset Indo/Hasil Embedding/21 Nov/embedding_matrix_XLMroBERTaLarge_1024D_21112024.npy',
        'mT5': '/home/basilmusyaffa19/Skripsi Basil/Embedding Matrix/Dataset Indo/Hasil Embedding/21 Nov/embedding_matrix_mt5Large_1024D_21112024.npy',
        'gloveWiki': '/home/basilmusyaffa19/Skripsi Basil/Embedding Matrix/Dataset Indo/Hasil Embedding/21 Nov/embedding_matrix_gloveWiki_50D_21112024.npy',
        'indoBERT': '/home/basilmusyaffa19/Skripsi Basil/Embedding Matrix/Dataset Indo/Hasil Embedding/21 Nov/embedding_matrix_indoBERTLarge_1024D_21112024.npy',
    }
    
    path = paths.get(model)
    
    if path:
        embedding_matrix = np.load(path)
        embedding_dim = embedding_matrix.shape[1]
        embedding_matrix = torch.tensor(embedding_matrix, dtype=torch.float32)
        return embedding_matrix, embedding_dim
    else:
        raise ValueError(f"Model '{model}' is not recognized")

def declare_model(model_llm, kernel_size, learning_rate):
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    print(f"Training CNN with Embedding {model_llm} \n")
    embedding_matrix, embedding_dim = prepare_embedding_matrix(model=model_llm)
    model = CNNModel(embedding_matrix, embedding_dim, kernel_size)
    model.to(device)
    criterion = nn.BCELoss()
    optimizer = optim.Adam(model.parameters(), 
                           lr=learning_rate,
                           weight_decay=1e-4)
    
    print('CNN Architecture:')
    print(model)
    print('')
    
    return device, model, criterion, optimizer

# %%
def binary_accuracy(y_pred, y_true):
    y_pred_tags = (y_pred > 0.5).long()
    correct_results_sum = (y_pred_tags == y_true).sum().float()
    acc = correct_results_sum / y_true.shape[0]
    return acc

def training(train_loader, val_loader, model, criterion, optimizer, device, epochs, patience, min_delta):
    torch.cuda.empty_cache()
    
    total_start_time = time.time()
    early_stopping = EarlyStopping(patience=patience, min_delta=min_delta)
    
    num_training_steps = epochs * len(train_loader)
    
    scheduler = get_linear_schedule_with_warmup(
        optimizer,
        num_warmup_steps=0,
        num_training_steps=num_training_steps
    )
    
    train_losses = []
    val_losses = []
    
    for epoch in range(epochs):
        model.train()
        train_loss_final = 0.0
        train_accuracy_final = 0.0
        for X_train, y_train in train_loader:
            X_train, y_train = X_train.to(device), y_train.to(device)
            optimizer.zero_grad()
            
            y_train_pred = model(X_train)
            train_loss = criterion(y_train_pred, y_train.float())
            train_accuracy = binary_accuracy(y_train_pred, y_train)
            
            train_loss.backward()
            optimizer.step()
            scheduler.step()
            
            train_loss_final += train_loss.item()
            train_accuracy_final += train_accuracy.item()
        avg_train_loss = train_loss_final / len(train_loader)
        avg_train_accuracy = train_accuracy_final / len(train_loader)
        train_losses.append(avg_train_loss)
        
        model.eval()
        val_loss_final = 0.0
        val_accuracy_final = 0.0
        with torch.no_grad():
            for X_val, y_val in val_loader:
                X_val, y_val = X_val.to(device), y_val.to(device)
                
                y_val_pred = model(X_val)
                val_loss = criterion(y_val_pred, y_val.float())
                val_accuracy = binary_accuracy(y_val_pred, y_val)
                
                val_loss_final += val_loss.item()
                val_accuracy_final += val_accuracy.item()
            avg_val_loss = val_loss_final / len(val_loader)
            avg_val_accuracy = val_accuracy_final / len(val_loader)
            val_losses.append(avg_val_loss)

        print(f'Epoch {epoch+1}/{epochs}, Train Loss: {avg_train_loss:.3f}, Val Loss: {avg_val_loss:.3f}, Train Accuracy: {avg_train_accuracy:.3f}, Val Accuracy: {avg_val_accuracy:.3f}')
    
        early_stopping(avg_val_loss)
    
        if early_stopping.early_stop:
            print("Early stopping")
            break
            
    total_end_time = time.time()
    total_time = total_end_time - total_start_time
    print(f'\nTotal Training Time: {total_time:.2f} seconds')
    
    # Plot learning curves
    plt.figure(figsize=(10, 5))
    plt.plot(train_losses, label='Train Loss')
    plt.plot(val_losses, label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Learning Curve')
    plt.legend()
    plt.show()

# %%
def evaluate(test_loader, model, criterion, optimizer, device):
    model.eval()
    test_loss_final = 0.0
    test_accuracy_final = 0.0
    y_pred_list = []
    y_test_list = []
    for X_test, y_test in test_loader:
        X_test, y_test = X_test.to(device), y_test.to(device)
        
        y_test_pred = model(X_test)
        test_loss = criterion(y_test_pred, y_test.float())
        test_accuracy = binary_accuracy(y_test_pred, y_test)
        
        test_loss_final += test_loss.item()
        test_accuracy_final += test_accuracy.item()
        
        y_pred_tags = (y_test_pred > 0.5).long()
        y_pred_list.append(y_pred_tags.cpu().numpy())
        y_test_list.append(y_test.cpu().numpy())
        
    avg_test_loss = test_loss_final / len(test_loader)
    avg_test_accuracy = test_accuracy_final / len(test_loader)
    
    print(f'Test Loss: {avg_test_loss:.3f}, Test Accuracy: {avg_test_accuracy:.3f}')
    print('')
    
    y_pred_list = np.concatenate([a.squeeze() for a in y_pred_list]).tolist()
    y_test_list = np.concatenate([a.squeeze() for a in y_test_list]).tolist()
    
    mcc = matthews_corrcoef(y_test_list, y_pred_list)
    print(f'Matthews Correlation Coefficient: {mcc:.3f}')
    print('')
    
    cm = confusion_matrix(y_test_list, y_pred_list)
    print('Classification Report:')
    print(classification_report(y_test_list, y_pred_list))
    print('')
    
    print('Confusion Matrix:')
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Predicted 0', 'Predicted 1'], yticklabels=['Actual 0', 'Actual 1'])
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.title('Confusion Matrix')
    plt.show()

# %%
LEARNING_RATE = 1e-4
EPOCH = 100
BATCH_SIZE = 64
KERNEL_SIZE = 3
PATIENCE = 10
MIN_DELTA= 1e-3

# %%
train_loader, val_loader, test_loader, vocab_size = prepare_data_loader(df, test_size=0.2, val_size=0.2, batch_size=BATCH_SIZE)
# Out:
# X_train Shape: (910, 44)
# X_val Shape: (46, 44)
# X_test Shape: (182, 44)
#
# y_train Class: 2
# y_val Class: 2
# y_test Class: 2

# %%
device, model, criterion, optimizer = declare_model(model_llm='gloveWiki', kernel_size=KERNEL_SIZE, learning_rate=LEARNING_RATE)
training(train_loader, val_loader, model, criterion, optimizer, device, epochs=EPOCH, patience=PATIENCE, min_delta=MIN_DELTA)
evaluate(test_loader, model, criterion, optimizer, device)
# Out:
# Training CNN with Embedding gloveWiki
#
# CNN Architecture:
# CNNModel(
#   (embedding): Embedding(2521, 50, padding_idx=0)
#   (layer_norm): LayerNorm((50,), eps=1e-05, elementwise_affine=True)
#   (conv1): Conv1d(50, 128, kernel_size=(3,), stride=(1,))
#   (bn1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (maxpool): MaxPool1d(kernel_size=3, stride=3, padding=0, dilation=1, ceil_mode=False)
#   (dropout): Dropout(p=0.2, inplace=False)
#   (conv2): Conv1d(128, 64, kernel_size=(3,), stride=(1,))
#   (bn2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (global_maxpool): AdaptiveMaxPool1d(output_size=1)
#   (fc1): Linear(in_features=64, out_features=32, bias=True)
#   (fc2): Linear(in_features=32, out_features=1, bias=True)
#   (relu): ReLU()
# )
#
# Epoch 1/100, Train Loss: 0.637, Val Loss: 0.626, Train Accuracy: 0.699, Val Accuracy: 0.935
# Epoch 2/100, Train Loss: 0.575, Val Loss: 0.529, Train Accuracy: 0.769, Val Accuracy: 0.935
# Epoch 3/100, Train Loss: 0.527, Val Loss: 0.457, Train Accuracy: 0.811, Val Accuracy: 0.957
# Epoch 4/100, Train Loss: 0.496, Val Loss: 0.403, Train Accuracy: 0.840, Val Accuracy: 0.957
# Epoch 5/100, Train Loss: 0.472, Val Loss: 0.366, Train Accuracy: 0.863, Val Accuracy: 0.978
# Epoch 6/100, Train Loss: 0.430, Val Loss: 0.327, Train Accuracy: 0.876, Val Accuracy: 0.978
# Epoch 7/100, Train Loss: 0.403, Val Loss: 0.291, Train Accuracy: 0.880, Val Accuracy: 0.957
# Epoch 8/100, Train Loss: 0.379, Val Loss: 0.257, Train Accuracy: 0.883, Val Accuracy: 0.978
# Epoch 9/100, Train Loss: 0.345, Val Loss: 0.229, Train Accuracy: 0.903, Val Accuracy: 0.978
# Epoch 10/100, Train Loss: 0.331, Val Loss: 0.214, Train Accuracy: 0.905, Val Accuracy: 0.957
# Epoch 11/100, Train Loss: 0.306, Val Loss: 0.197, Train Accuracy: 0.915, Val Accuracy: 0.957
# Epoch 12/100, Train Loss: 0.305, Val Loss: 0.184, Train Accuracy: 0.912, Val Accuracy: 0.957
# Epoch 13/100, Train Loss: 0.276, Val Loss: 0.176, Train Accuracy: 0.924, Val Accuracy: 0.935
# Epoch 14/100, Train Loss: 0.261, Val Loss: 0.166, Train Accuracy: 0.916, Val Accuracy: 0.957
# Epoch 15/100, Train Loss: 0.253, Val Loss: 0.154, Train Accuracy: 0.942, Val Accuracy: 0.978
# Epoch 16/100, Train Loss: 0.255, Val Loss: 0.144, Train Accuracy: 0.913, Val Accuracy: 0.957
# Epoch 17/100, Train Loss: 0.241, Val Loss: 0.141, Train Accuracy: 0.921, Val Accuracy: 0.957
# Epoch 18/100, Train Loss: 0.272, Val Loss: 0.132, Train Accuracy: 0.912, Val Accuracy: 0.978
# Epoch 19/100, Train Loss: 0.216, Val Loss: 0.130, Train Accuracy: 0.932, Val Accuracy: 0.978
# Epoch 20/100, Train Loss: 0.206, Val Loss: 0.125, Train Accuracy: 0.943, Val Accuracy: 0.978
# Epoch 21/100, Train Loss: 0.198, Val Loss: 0.124, Train Accuracy: 0.946, Val Accuracy: 0.957
# Epoch 22/100, Train Loss: 0.200, Val Loss: 0.119, Train Accuracy: 0.932, Val Accuracy: 0.957
# Epoch 23/100, Train Loss: 0.189, Val Loss: 0.117, Train Accuracy: 0.942, Val Accuracy: 0.957
# Epoch 24/100, Train Loss: 0.192, Val Loss: 0.112, Train Accuracy: 0.945, Val Accuracy: 0.957
# Epoch 25/100, Train Loss: 0.189, Val Loss: 0.107, Train Accuracy: 0.941, Val Accuracy: 0.978
# Epoch 26/100, Train Loss: 0.179, Val Loss: 0.108, Train Accuracy: 0.943, Val Accuracy: 0.978
# Epoch 27/100, Train Loss: 0.182, Val Loss: 0.102, Train Accuracy: 0.942, Val Accuracy: 0.978
# Epoch 28/100, Train Loss: 0.172, Val Loss: 0.103, Train Accuracy: 0.946, Val Accuracy: 0.978
# Epoch 29/100, Train Loss: 0.156, Val Loss: 0.101, Train Accuracy: 0.952, Val Accuracy: 0.978
# Epoch 30/100, Train Loss: 0.161, Val Loss: 0.104, Train Accuracy: 0.953, Val Accuracy: 0.978
# Epoch 31/100, Train Loss: 0.191, Val Loss: 0.095, Train Accuracy: 0.940, Val Accuracy: 0.978
# Epoch 32/100, Train Loss: 0.141, Val Loss: 0.098, Train Accuracy: 0.960, Val Accuracy: 0.978
# Epoch 33/100, Train Loss: 0.157, Val Loss: 0.094, Train Accuracy: 0.954, Val Accuracy: 0.978
# Epoch 34/100, Train Loss: 0.158, Val Loss: 0.099, Train Accuracy: 0.958, Val Accuracy: 0.978
# Epoch 35/100, Train Loss: 0.146, Val Loss: 0.092, Train Accuracy: 0.959, Val Accuracy: 0.978
# Epoch 36/100, Train Loss: 0.142, Val Loss: 0.095, Train Accuracy: 0.954, Val Accuracy: 0.978
# Epoch 37/100, Train Loss: 0.131, Val Loss: 0.087, Train Accuracy: 0.955, Val Accuracy: 0.978
# Epoch 38/100, Train Loss: 0.142, Val Loss: 0.098, Train Accuracy: 0.959, Val Accuracy: 0.978
# Epoch 39/100, Train Loss: 0.139, Val Loss: 0.083, Train Accuracy: 0.958, Val Accuracy: 0.978
# Epoch 40/100, Train Loss: 0.135, Val Loss: 0.079, Train Accuracy: 0.962, Val Accuracy: 0.978
# Epoch 41/100, Train Loss: 0.151, Val Loss: 0.082, Train Accuracy: 0.951, Val Accuracy: 0.978
# Epoch 42/100, Train Loss: 0.135, Val Loss: 0.103, Train Accuracy: 0.955, Val Accuracy: 0.957
# Epoch 43/100, Train Loss: 0.119, Val Loss: 0.090, Train Accuracy: 0.965, Val Accuracy: 0.978
# Epoch 44/100, Train Loss: 0.126, Val Loss: 0.089, Train Accuracy: 0.965, Val Accuracy: 0.978
# Epoch 45/100, Train Loss: 0.114, Val Loss: 0.089, Train Accuracy: 0.971, Val Accuracy: 0.978
# Epoch 46/100, Train Loss: 0.113, Val Loss: 0.084, Train Accuracy: 0.964, Val Accuracy: 0.978
# Epoch 47/100, Train Loss: 0.114, Val Loss: 0.081, Train Accuracy: 0.966, Val Accuracy: 0.978
# Epoch 48/100, Train Loss: 0.111, Val Loss: 0.087, Train Accuracy: 0.965, Val Accuracy: 0.978
# Epoch 49/100, Train Loss: 0.103, Val Loss: 0.082, Train Accuracy: 0.972, Val Accuracy: 0.978
# Epoch 50/100, Train Loss: 0.122, Val Loss: 0.084, Train Accuracy: 0.957, Val Accuracy: 0.978
# Early stopping
#
# Total Training Time: 6.51 seconds
# Test Loss: 0.178, Test Accuracy: 0.946
#
# Matthews Correlation Coefficient: 0.891
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.92      0.94        91
#          1.0       0.93      0.97      0.95        91
#
#     accuracy                           0.95       182
#    macro avg       0.95      0.95      0.95       182
# weighted avg       0.95      0.95      0.95       182
#
#
# Confusion Matrix:

# %%
device, model, criterion, optimizer = declare_model(model_llm='indoBERT', kernel_size=KERNEL_SIZE, learning_rate=LEARNING_RATE)
training(train_loader, val_loader, model, criterion, optimizer, device, epochs=EPOCH, patience=PATIENCE, min_delta=MIN_DELTA)
evaluate(test_loader, model, criterion, optimizer, device)
# Out:
# Training CNN with Embedding indoBERT
#
# CNN Architecture:
# CNNModel(
#   (embedding): Embedding(2521, 1024, padding_idx=0)
#   (layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#   (conv1): Conv1d(1024, 128, kernel_size=(3,), stride=(1,))
#   (bn1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (maxpool): MaxPool1d(kernel_size=3, stride=3, padding=0, dilation=1, ceil_mode=False)
#   (dropout): Dropout(p=0.2, inplace=False)
#   (conv2): Conv1d(128, 64, kernel_size=(3,), stride=(1,))
#   (bn2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (global_maxpool): AdaptiveMaxPool1d(output_size=1)
#   (fc1): Linear(in_features=64, out_features=32, bias=True)
#   (fc2): Linear(in_features=32, out_features=1, bias=True)
#   (relu): ReLU()
# )
#
# Epoch 1/100, Train Loss: 0.636, Val Loss: 0.632, Train Accuracy: 0.657, Val Accuracy: 0.696
# Epoch 2/100, Train Loss: 0.575, Val Loss: 0.549, Train Accuracy: 0.766, Val Accuracy: 0.826
# Epoch 3/100, Train Loss: 0.563, Val Loss: 0.502, Train Accuracy: 0.773, Val Accuracy: 0.870
# Epoch 4/100, Train Loss: 0.532, Val Loss: 0.464, Train Accuracy: 0.797, Val Accuracy: 0.913
# Epoch 5/100, Train Loss: 0.508, Val Loss: 0.437, Train Accuracy: 0.802, Val Accuracy: 0.935
# Epoch 6/100, Train Loss: 0.510, Val Loss: 0.414, Train Accuracy: 0.790, Val Accuracy: 0.935
# Epoch 7/100, Train Loss: 0.500, Val Loss: 0.414, Train Accuracy: 0.793, Val Accuracy: 0.935
# Epoch 8/100, Train Loss: 0.483, Val Loss: 0.401, Train Accuracy: 0.807, Val Accuracy: 0.935
# Epoch 9/100, Train Loss: 0.474, Val Loss: 0.370, Train Accuracy: 0.821, Val Accuracy: 0.935
# Epoch 10/100, Train Loss: 0.468, Val Loss: 0.385, Train Accuracy: 0.820, Val Accuracy: 0.935
# Epoch 11/100, Train Loss: 0.453, Val Loss: 0.347, Train Accuracy: 0.810, Val Accuracy: 0.935
# Epoch 12/100, Train Loss: 0.438, Val Loss: 0.348, Train Accuracy: 0.824, Val Accuracy: 0.935
# Epoch 13/100, Train Loss: 0.436, Val Loss: 0.331, Train Accuracy: 0.828, Val Accuracy: 0.935
# Epoch 14/100, Train Loss: 0.445, Val Loss: 0.340, Train Accuracy: 0.820, Val Accuracy: 0.935
# Epoch 15/100, Train Loss: 0.458, Val Loss: 0.348, Train Accuracy: 0.805, Val Accuracy: 0.935
# Epoch 16/100, Train Loss: 0.447, Val Loss: 0.378, Train Accuracy: 0.824, Val Accuracy: 0.891
# Epoch 17/100, Train Loss: 0.440, Val Loss: 0.343, Train Accuracy: 0.820, Val Accuracy: 0.913
# Epoch 18/100, Train Loss: 0.428, Val Loss: 0.402, Train Accuracy: 0.836, Val Accuracy: 0.848
# Epoch 19/100, Train Loss: 0.411, Val Loss: 0.341, Train Accuracy: 0.835, Val Accuracy: 0.935
# Epoch 20/100, Train Loss: 0.422, Val Loss: 0.446, Train Accuracy: 0.833, Val Accuracy: 0.739
# Epoch 21/100, Train Loss: 0.403, Val Loss: 0.346, Train Accuracy: 0.836, Val Accuracy: 0.935
# Epoch 22/100, Train Loss: 0.411, Val Loss: 0.359, Train Accuracy: 0.837, Val Accuracy: 0.913
# Epoch 23/100, Train Loss: 0.402, Val Loss: 0.349, Train Accuracy: 0.840, Val Accuracy: 0.913
# Early stopping
#
# Total Training Time: 4.47 seconds
# Test Loss: 0.520, Test Accuracy: 0.802
#
# Matthews Correlation Coefficient: 0.617
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.70      0.78        91
#          1.0       0.75      0.90      0.82        91
#
#     accuracy                           0.80       182
#    macro avg       0.81      0.80      0.80       182
# weighted avg       0.81      0.80      0.80       182
#
#
# Confusion Matrix:

# %%
device, model, criterion, optimizer = declare_model(model_llm='XLM-R', kernel_size=KERNEL_SIZE, learning_rate=LEARNING_RATE)
training(train_loader, val_loader, model, criterion, optimizer, device, epochs=EPOCH, patience=PATIENCE, min_delta=MIN_DELTA)
evaluate(test_loader, model, criterion, optimizer, device)
# Out:
# Training CNN with Embedding XLM-R
#
# CNN Architecture:
# CNNModel(
#   (embedding): Embedding(2521, 1024, padding_idx=0)
#   (layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#   (conv1): Conv1d(1024, 128, kernel_size=(3,), stride=(1,))
#   (bn1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (maxpool): MaxPool1d(kernel_size=3, stride=3, padding=0, dilation=1, ceil_mode=False)
#   (dropout): Dropout(p=0.2, inplace=False)
#   (conv2): Conv1d(128, 64, kernel_size=(3,), stride=(1,))
#   (bn2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (global_maxpool): AdaptiveMaxPool1d(output_size=1)
#   (fc1): Linear(in_features=64, out_features=32, bias=True)
#   (fc2): Linear(in_features=32, out_features=1, bias=True)
#   (relu): ReLU()
# )
#
# Epoch 1/100, Train Loss: 0.652, Val Loss: 0.662, Train Accuracy: 0.619, Val Accuracy: 0.826
# Epoch 2/100, Train Loss: 0.591, Val Loss: 0.610, Train Accuracy: 0.743, Val Accuracy: 0.848
# Epoch 3/100, Train Loss: 0.560, Val Loss: 0.547, Train Accuracy: 0.768, Val Accuracy: 0.935
# Epoch 4/100, Train Loss: 0.510, Val Loss: 0.470, Train Accuracy: 0.822, Val Accuracy: 0.935
# Epoch 5/100, Train Loss: 0.471, Val Loss: 0.443, Train Accuracy: 0.830, Val Accuracy: 0.913
# Epoch 6/100, Train Loss: 0.451, Val Loss: 0.391, Train Accuracy: 0.844, Val Accuracy: 0.913
# Epoch 7/100, Train Loss: 0.411, Val Loss: 0.364, Train Accuracy: 0.866, Val Accuracy: 0.957
# Epoch 8/100, Train Loss: 0.390, Val Loss: 0.337, Train Accuracy: 0.888, Val Accuracy: 0.957
# Epoch 9/100, Train Loss: 0.361, Val Loss: 0.315, Train Accuracy: 0.896, Val Accuracy: 0.935
# Epoch 10/100, Train Loss: 0.326, Val Loss: 0.299, Train Accuracy: 0.915, Val Accuracy: 0.935
# Epoch 11/100, Train Loss: 0.311, Val Loss: 0.251, Train Accuracy: 0.909, Val Accuracy: 0.957
# Epoch 12/100, Train Loss: 0.288, Val Loss: 0.211, Train Accuracy: 0.931, Val Accuracy: 0.978
# Epoch 13/100, Train Loss: 0.257, Val Loss: 0.227, Train Accuracy: 0.935, Val Accuracy: 0.957
# Epoch 14/100, Train Loss: 0.244, Val Loss: 0.184, Train Accuracy: 0.940, Val Accuracy: 1.000
# Epoch 15/100, Train Loss: 0.220, Val Loss: 0.196, Train Accuracy: 0.949, Val Accuracy: 0.957
# Epoch 16/100, Train Loss: 0.199, Val Loss: 0.163, Train Accuracy: 0.961, Val Accuracy: 0.978
# Epoch 17/100, Train Loss: 0.192, Val Loss: 0.177, Train Accuracy: 0.963, Val Accuracy: 0.978
# Epoch 18/100, Train Loss: 0.184, Val Loss: 0.148, Train Accuracy: 0.961, Val Accuracy: 1.000
# Epoch 19/100, Train Loss: 0.167, Val Loss: 0.147, Train Accuracy: 0.970, Val Accuracy: 0.978
# Epoch 20/100, Train Loss: 0.147, Val Loss: 0.153, Train Accuracy: 0.975, Val Accuracy: 0.978
# Epoch 21/100, Train Loss: 0.144, Val Loss: 0.130, Train Accuracy: 0.975, Val Accuracy: 0.978
# Epoch 22/100, Train Loss: 0.124, Val Loss: 0.096, Train Accuracy: 0.983, Val Accuracy: 1.000
# Epoch 23/100, Train Loss: 0.120, Val Loss: 0.097, Train Accuracy: 0.982, Val Accuracy: 1.000
# Epoch 24/100, Train Loss: 0.115, Val Loss: 0.094, Train Accuracy: 0.985, Val Accuracy: 1.000
# Epoch 25/100, Train Loss: 0.100, Val Loss: 0.105, Train Accuracy: 0.986, Val Accuracy: 0.978
# Epoch 26/100, Train Loss: 0.087, Val Loss: 0.110, Train Accuracy: 0.993, Val Accuracy: 0.978
# Epoch 27/100, Train Loss: 0.087, Val Loss: 0.128, Train Accuracy: 0.994, Val Accuracy: 0.978
# Epoch 28/100, Train Loss: 0.086, Val Loss: 0.078, Train Accuracy: 0.989, Val Accuracy: 1.000
# Epoch 29/100, Train Loss: 0.084, Val Loss: 0.070, Train Accuracy: 0.990, Val Accuracy: 1.000
# Epoch 30/100, Train Loss: 0.074, Val Loss: 0.064, Train Accuracy: 0.990, Val Accuracy: 1.000
# Epoch 31/100, Train Loss: 0.064, Val Loss: 0.066, Train Accuracy: 0.992, Val Accuracy: 1.000
# Epoch 32/100, Train Loss: 0.062, Val Loss: 0.059, Train Accuracy: 0.996, Val Accuracy: 1.000
# Epoch 33/100, Train Loss: 0.058, Val Loss: 0.081, Train Accuracy: 0.996, Val Accuracy: 0.978
# Epoch 34/100, Train Loss: 0.063, Val Loss: 0.069, Train Accuracy: 0.993, Val Accuracy: 0.978
# Epoch 35/100, Train Loss: 0.050, Val Loss: 0.083, Train Accuracy: 0.997, Val Accuracy: 0.978
# Epoch 36/100, Train Loss: 0.052, Val Loss: 0.055, Train Accuracy: 0.998, Val Accuracy: 1.000
# Epoch 37/100, Train Loss: 0.044, Val Loss: 0.066, Train Accuracy: 0.998, Val Accuracy: 0.978
# Epoch 38/100, Train Loss: 0.045, Val Loss: 0.058, Train Accuracy: 0.999, Val Accuracy: 1.000
# Epoch 39/100, Train Loss: 0.040, Val Loss: 0.062, Train Accuracy: 0.998, Val Accuracy: 0.978
# Epoch 40/100, Train Loss: 0.045, Val Loss: 0.091, Train Accuracy: 0.996, Val Accuracy: 0.978
# Epoch 41/100, Train Loss: 0.032, Val Loss: 0.054, Train Accuracy: 0.999, Val Accuracy: 1.000
# Epoch 42/100, Train Loss: 0.032, Val Loss: 0.046, Train Accuracy: 0.999, Val Accuracy: 1.000
# Epoch 43/100, Train Loss: 0.034, Val Loss: 0.069, Train Accuracy: 0.999, Val Accuracy: 0.978
# Epoch 44/100, Train Loss: 0.031, Val Loss: 0.054, Train Accuracy: 0.999, Val Accuracy: 1.000
# Epoch 45/100, Train Loss: 0.036, Val Loss: 0.044, Train Accuracy: 0.996, Val Accuracy: 1.000
# Epoch 46/100, Train Loss: 0.033, Val Loss: 0.052, Train Accuracy: 0.999, Val Accuracy: 1.000
# Epoch 47/100, Train Loss: 0.031, Val Loss: 0.042, Train Accuracy: 0.997, Val Accuracy: 1.000
# Epoch 48/100, Train Loss: 0.030, Val Loss: 0.033, Train Accuracy: 0.998, Val Accuracy: 1.000
# Epoch 49/100, Train Loss: 0.026, Val Loss: 0.034, Train Accuracy: 0.999, Val Accuracy: 1.000
# Epoch 50/100, Train Loss: 0.024, Val Loss: 0.041, Train Accuracy: 0.999, Val Accuracy: 1.000
# Epoch 51/100, Train Loss: 0.026, Val Loss: 0.044, Train Accuracy: 0.998, Val Accuracy: 1.000
# Epoch 52/100, Train Loss: 0.028, Val Loss: 0.048, Train Accuracy: 0.997, Val Accuracy: 1.000
# Epoch 53/100, Train Loss: 0.025, Val Loss: 0.035, Train Accuracy: 0.999, Val Accuracy: 1.000
# Epoch 54/100, Train Loss: 0.023, Val Loss: 0.050, Train Accuracy: 1.000, Val Accuracy: 1.000
# Epoch 55/100, Train Loss: 0.021, Val Loss: 0.058, Train Accuracy: 0.999, Val Accuracy: 0.978
# Epoch 56/100, Train Loss: 0.023, Val Loss: 0.031, Train Accuracy: 0.999, Val Accuracy: 1.000
# Epoch 57/100, Train Loss: 0.020, Val Loss: 0.043, Train Accuracy: 0.999, Val Accuracy: 1.000
# Epoch 58/100, Train Loss: 0.021, Val Loss: 0.031, Train Accuracy: 0.998, Val Accuracy: 1.000
# Epoch 59/100, Train Loss: 0.021, Val Loss: 0.044, Train Accuracy: 0.998, Val Accuracy: 0.978
# Epoch 60/100, Train Loss: 0.023, Val Loss: 0.030, Train Accuracy: 0.998, Val Accuracy: 1.000
# Epoch 61/100, Train Loss: 0.020, Val Loss: 0.051, Train Accuracy: 0.999, Val Accuracy: 0.978
# Epoch 62/100, Train Loss: 0.018, Val Loss: 0.036, Train Accuracy: 0.999, Val Accuracy: 1.000
# Epoch 63/100, Train Loss: 0.016, Val Loss: 0.036, Train Accuracy: 1.000, Val Accuracy: 1.000
# Epoch 64/100, Train Loss: 0.016, Val Loss: 0.047, Train Accuracy: 0.999, Val Accuracy: 0.978
# Epoch 65/100, Train Loss: 0.015, Val Loss: 0.041, Train Accuracy: 1.000, Val Accuracy: 0.978
# Epoch 66/100, Train Loss: 0.016, Val Loss: 0.044, Train Accuracy: 1.000, Val Accuracy: 0.978
# Epoch 67/100, Train Loss: 0.015, Val Loss: 0.040, Train Accuracy: 0.999, Val Accuracy: 1.000
# Epoch 68/100, Train Loss: 0.015, Val Loss: 0.033, Train Accuracy: 0.999, Val Accuracy: 1.000
# Epoch 69/100, Train Loss: 0.015, Val Loss: 0.039, Train Accuracy: 0.999, Val Accuracy: 0.978
# Epoch 70/100, Train Loss: 0.015, Val Loss: 0.039, Train Accuracy: 1.000, Val Accuracy: 0.978
# Early stopping
#
# Total Training Time: 5.84 seconds
# Test Loss: 0.208, Test Accuracy: 0.937
#
# Matthews Correlation Coefficient: 0.880
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.97      0.94        91
#          1.0       0.97      0.91      0.94        91
#
#     accuracy                           0.94       182
#    macro avg       0.94      0.94      0.94       182
# weighted avg       0.94      0.94      0.94       182
#
#
# Confusion Matrix:

# %%
device, model, criterion, optimizer = declare_model(model_llm='mT5', kernel_size=KERNEL_SIZE, learning_rate=LEARNING_RATE)
training(train_loader, val_loader, model, criterion, optimizer, device, epochs=EPOCH, patience=PATIENCE, min_delta=MIN_DELTA)
evaluate(test_loader, model, criterion, optimizer, device)
# Out:
# Training CNN with Embedding mT5
#
# CNN Architecture:
# CNNModel(
#   (embedding): Embedding(2521, 1024, padding_idx=0)
#   (layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#   (conv1): Conv1d(1024, 128, kernel_size=(3,), stride=(1,))
#   (bn1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (maxpool): MaxPool1d(kernel_size=3, stride=3, padding=0, dilation=1, ceil_mode=False)
#   (dropout): Dropout(p=0.2, inplace=False)
#   (conv2): Conv1d(128, 64, kernel_size=(3,), stride=(1,))
#   (bn2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (global_maxpool): AdaptiveMaxPool1d(output_size=1)
#   (fc1): Linear(in_features=64, out_features=32, bias=True)
#   (fc2): Linear(in_features=32, out_features=1, bias=True)
#   (relu): ReLU()
# )
#
# Epoch 1/100, Train Loss: 0.636, Val Loss: 0.620, Train Accuracy: 0.552, Val Accuracy: 0.674
# Epoch 2/100, Train Loss: 0.556, Val Loss: 0.526, Train Accuracy: 0.717, Val Accuracy: 0.870
# Epoch 3/100, Train Loss: 0.492, Val Loss: 0.430, Train Accuracy: 0.825, Val Accuracy: 0.957
# Epoch 4/100, Train Loss: 0.446, Val Loss: 0.398, Train Accuracy: 0.864, Val Accuracy: 0.978
# Epoch 5/100, Train Loss: 0.407, Val Loss: 0.326, Train Accuracy: 0.894, Val Accuracy: 0.957
# Epoch 6/100, Train Loss: 0.375, Val Loss: 0.288, Train Accuracy: 0.923, Val Accuracy: 0.978
# Epoch 7/100, Train Loss: 0.350, Val Loss: 0.280, Train Accuracy: 0.913, Val Accuracy: 1.000
# Epoch 8/100, Train Loss: 0.314, Val Loss: 0.238, Train Accuracy: 0.935, Val Accuracy: 1.000
# Epoch 9/100, Train Loss: 0.281, Val Loss: 0.219, Train Accuracy: 0.946, Val Accuracy: 1.000
# Epoch 10/100, Train Loss: 0.266, Val Loss: 0.195, Train Accuracy: 0.954, Val Accuracy: 1.000
# Epoch 11/100, Train Loss: 0.227, Val Loss: 0.172, Train Accuracy: 0.973, Val Accuracy: 0.978
# Epoch 12/100, Train Loss: 0.207, Val Loss: 0.159, Train Accuracy: 0.971, Val Accuracy: 1.000
# Epoch 13/100, Train Loss: 0.186, Val Loss: 0.146, Train Accuracy: 0.970, Val Accuracy: 1.000
# Epoch 14/100, Train Loss: 0.171, Val Loss: 0.133, Train Accuracy: 0.978, Val Accuracy: 1.000
# Epoch 15/100, Train Loss: 0.151, Val Loss: 0.122, Train Accuracy: 0.978, Val Accuracy: 1.000
# Epoch 16/100, Train Loss: 0.142, Val Loss: 0.107, Train Accuracy: 0.988, Val Accuracy: 1.000
# Epoch 17/100, Train Loss: 0.124, Val Loss: 0.100, Train Accuracy: 0.986, Val Accuracy: 1.000
# Epoch 18/100, Train Loss: 0.111, Val Loss: 0.096, Train Accuracy: 0.989, Val Accuracy: 1.000
# Epoch 19/100, Train Loss: 0.099, Val Loss: 0.091, Train Accuracy: 0.997, Val Accuracy: 1.000
# Epoch 20/100, Train Loss: 0.094, Val Loss: 0.077, Train Accuracy: 0.994, Val Accuracy: 1.000
# Epoch 21/100, Train Loss: 0.083, Val Loss: 0.086, Train Accuracy: 0.992, Val Accuracy: 1.000
# Epoch 22/100, Train Loss: 0.076, Val Loss: 0.069, Train Accuracy: 0.999, Val Accuracy: 1.000
# Epoch 23/100, Train Loss: 0.069, Val Loss: 0.061, Train Accuracy: 1.000, Val Accuracy: 1.000
# Epoch 24/100, Train Loss: 0.063, Val Loss: 0.054, Train Accuracy: 0.998, Val Accuracy: 1.000
# Epoch 25/100, Train Loss: 0.062, Val Loss: 0.064, Train Accuracy: 0.995, Val Accuracy: 1.000
# Epoch 26/100, Train Loss: 0.053, Val Loss: 0.061, Train Accuracy: 1.000, Val Accuracy: 1.000
# Epoch 27/100, Train Loss: 0.050, Val Loss: 0.059, Train Accuracy: 0.999, Val Accuracy: 1.000
# Epoch 28/100, Train Loss: 0.045, Val Loss: 0.048, Train Accuracy: 1.000, Val Accuracy: 1.000
# Epoch 29/100, Train Loss: 0.047, Val Loss: 0.047, Train Accuracy: 0.995, Val Accuracy: 1.000
# Epoch 30/100, Train Loss: 0.039, Val Loss: 0.063, Train Accuracy: 1.000, Val Accuracy: 0.978
# Epoch 31/100, Train Loss: 0.037, Val Loss: 0.050, Train Accuracy: 1.000, Val Accuracy: 1.000
# Epoch 32/100, Train Loss: 0.033, Val Loss: 0.041, Train Accuracy: 1.000, Val Accuracy: 1.000
# Epoch 33/100, Train Loss: 0.031, Val Loss: 0.037, Train Accuracy: 1.000, Val Accuracy: 1.000
# Epoch 34/100, Train Loss: 0.030, Val Loss: 0.069, Train Accuracy: 1.000, Val Accuracy: 0.978
# Epoch 35/100, Train Loss: 0.030, Val Loss: 0.055, Train Accuracy: 1.000, Val Accuracy: 0.978
# Epoch 36/100, Train Loss: 0.027, Val Loss: 0.043, Train Accuracy: 1.000, Val Accuracy: 1.000
# Epoch 37/100, Train Loss: 0.025, Val Loss: 0.036, Train Accuracy: 0.999, Val Accuracy: 1.000
# Epoch 38/100, Train Loss: 0.024, Val Loss: 0.031, Train Accuracy: 1.000, Val Accuracy: 1.000
# Epoch 39/100, Train Loss: 0.025, Val Loss: 0.055, Train Accuracy: 0.999, Val Accuracy: 0.978
# Epoch 40/100, Train Loss: 0.020, Val Loss: 0.037, Train Accuracy: 1.000, Val Accuracy: 1.000
# Epoch 41/100, Train Loss: 0.019, Val Loss: 0.035, Train Accuracy: 1.000, Val Accuracy: 1.000
# Epoch 42/100, Train Loss: 0.020, Val Loss: 0.051, Train Accuracy: 1.000, Val Accuracy: 0.978
# Epoch 43/100, Train Loss: 0.019, Val Loss: 0.035, Train Accuracy: 1.000, Val Accuracy: 1.000
# Epoch 44/100, Train Loss: 0.019, Val Loss: 0.029, Train Accuracy: 1.000, Val Accuracy: 1.000
# Epoch 45/100, Train Loss: 0.016, Val Loss: 0.035, Train Accuracy: 1.000, Val Accuracy: 1.000
# Epoch 46/100, Train Loss: 0.017, Val Loss: 0.042, Train Accuracy: 1.000, Val Accuracy: 0.978
# Epoch 47/100, Train Loss: 0.015, Val Loss: 0.037, Train Accuracy: 1.000, Val Accuracy: 1.000
# Epoch 48/100, Train Loss: 0.014, Val Loss: 0.039, Train Accuracy: 1.000, Val Accuracy: 1.000
# Epoch 49/100, Train Loss: 0.016, Val Loss: 0.035, Train Accuracy: 1.000, Val Accuracy: 1.000
# Epoch 50/100, Train Loss: 0.013, Val Loss: 0.033, Train Accuracy: 1.000, Val Accuracy: 1.000
# Epoch 51/100, Train Loss: 0.014, Val Loss: 0.055, Train Accuracy: 1.000, Val Accuracy: 0.957
# Epoch 52/100, Train Loss: 0.014, Val Loss: 0.033, Train Accuracy: 1.000, Val Accuracy: 1.000
# Epoch 53/100, Train Loss: 0.011, Val Loss: 0.022, Train Accuracy: 1.000, Val Accuracy: 1.000
# Epoch 54/100, Train Loss: 0.013, Val Loss: 0.042, Train Accuracy: 1.000, Val Accuracy: 0.978
# Epoch 55/100, Train Loss: 0.012, Val Loss: 0.029, Train Accuracy: 1.000, Val Accuracy: 1.000
# Epoch 56/100, Train Loss: 0.010, Val Loss: 0.036, Train Accuracy: 1.000, Val Accuracy: 0.978
# Epoch 57/100, Train Loss: 0.011, Val Loss: 0.026, Train Accuracy: 1.000, Val Accuracy: 1.000
# Epoch 58/100, Train Loss: 0.010, Val Loss: 0.033, Train Accuracy: 1.000, Val Accuracy: 0.978
# Epoch 59/100, Train Loss: 0.011, Val Loss: 0.032, Train Accuracy: 1.000, Val Accuracy: 1.000
# Epoch 60/100, Train Loss: 0.009, Val Loss: 0.022, Train Accuracy: 1.000, Val Accuracy: 1.000
# Epoch 61/100, Train Loss: 0.010, Val Loss: 0.037, Train Accuracy: 1.000, Val Accuracy: 0.978
# Epoch 62/100, Train Loss: 0.008, Val Loss: 0.027, Train Accuracy: 1.000, Val Accuracy: 1.000
# Epoch 63/100, Train Loss: 0.009, Val Loss: 0.029, Train Accuracy: 1.000, Val Accuracy: 1.000
# Early stopping
#
# Total Training Time: 5.65 seconds
# Test Loss: 0.064, Test Accuracy: 0.972
#
# Matthews Correlation Coefficient: 0.945
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.98      0.97        91
#          1.0       0.98      0.97      0.97        91
#
#     accuracy                           0.97       182
#    macro avg       0.97      0.97      0.97       182
# weighted avg       0.97      0.97      0.97       182
#
#
# Confusion Matrix:

# %%
device, model, criterion, optimizer = declare_model(model_llm='gpt2', kernel_size=KERNEL_SIZE, learning_rate=LEARNING_RATE)
training(train_loader, val_loader, model, criterion, optimizer, device, epochs=EPOCH, patience=PATIENCE, min_delta=MIN_DELTA)
evaluate(test_loader, model, criterion, optimizer, device)
# Out:
# Training CNN with Embedding gpt2
#
# CNN Architecture:
# CNNModel(
#   (embedding): Embedding(2521, 1024, padding_idx=0)
#   (layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#   (conv1): Conv1d(1024, 128, kernel_size=(3,), stride=(1,))
#   (bn1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (maxpool): MaxPool1d(kernel_size=3, stride=3, padding=0, dilation=1, ceil_mode=False)
#   (dropout): Dropout(p=0.2, inplace=False)
#   (conv2): Conv1d(128, 64, kernel_size=(3,), stride=(1,))
#   (bn2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (global_maxpool): AdaptiveMaxPool1d(output_size=1)
#   (fc1): Linear(in_features=64, out_features=32, bias=True)
#   (fc2): Linear(in_features=32, out_features=1, bias=True)
#   (relu): ReLU()
# )
#
# Epoch 1/100, Train Loss: 0.711, Val Loss: 0.695, Train Accuracy: 0.503, Val Accuracy: 0.500
# Epoch 2/100, Train Loss: 0.640, Val Loss: 0.658, Train Accuracy: 0.633, Val Accuracy: 0.500
# Epoch 3/100, Train Loss: 0.603, Val Loss: 0.576, Train Accuracy: 0.715, Val Accuracy: 0.826
# Epoch 4/100, Train Loss: 0.562, Val Loss: 0.525, Train Accuracy: 0.753, Val Accuracy: 0.935
# Epoch 5/100, Train Loss: 0.512, Val Loss: 0.451, Train Accuracy: 0.801, Val Accuracy: 0.935
# Epoch 6/100, Train Loss: 0.490, Val Loss: 0.411, Train Accuracy: 0.825, Val Accuracy: 0.935
# Epoch 7/100, Train Loss: 0.475, Val Loss: 0.369, Train Accuracy: 0.824, Val Accuracy: 0.935
# Epoch 8/100, Train Loss: 0.453, Val Loss: 0.342, Train Accuracy: 0.844, Val Accuracy: 0.957
# Epoch 9/100, Train Loss: 0.425, Val Loss: 0.353, Train Accuracy: 0.852, Val Accuracy: 0.913
# Epoch 10/100, Train Loss: 0.396, Val Loss: 0.289, Train Accuracy: 0.868, Val Accuracy: 0.957
# Epoch 11/100, Train Loss: 0.374, Val Loss: 0.278, Train Accuracy: 0.887, Val Accuracy: 0.957
# Epoch 12/100, Train Loss: 0.354, Val Loss: 0.261, Train Accuracy: 0.889, Val Accuracy: 0.935
# Epoch 13/100, Train Loss: 0.338, Val Loss: 0.232, Train Accuracy: 0.905, Val Accuracy: 0.957
# Epoch 14/100, Train Loss: 0.315, Val Loss: 0.234, Train Accuracy: 0.906, Val Accuracy: 0.957
# Epoch 15/100, Train Loss: 0.288, Val Loss: 0.184, Train Accuracy: 0.928, Val Accuracy: 0.978
# Epoch 16/100, Train Loss: 0.278, Val Loss: 0.186, Train Accuracy: 0.921, Val Accuracy: 0.957
# Epoch 17/100, Train Loss: 0.269, Val Loss: 0.177, Train Accuracy: 0.912, Val Accuracy: 1.000
# Epoch 18/100, Train Loss: 0.232, Val Loss: 0.149, Train Accuracy: 0.942, Val Accuracy: 0.978
# Epoch 19/100, Train Loss: 0.229, Val Loss: 0.129, Train Accuracy: 0.959, Val Accuracy: 1.000
# Epoch 20/100, Train Loss: 0.203, Val Loss: 0.127, Train Accuracy: 0.957, Val Accuracy: 1.000
# Epoch 21/100, Train Loss: 0.200, Val Loss: 0.100, Train Accuracy: 0.959, Val Accuracy: 1.000
# Epoch 22/100, Train Loss: 0.171, Val Loss: 0.117, Train Accuracy: 0.956, Val Accuracy: 0.978
# Epoch 23/100, Train Loss: 0.172, Val Loss: 0.123, Train Accuracy: 0.960, Val Accuracy: 0.978
# Epoch 24/100, Train Loss: 0.178, Val Loss: 0.081, Train Accuracy: 0.953, Val Accuracy: 1.000
# Epoch 25/100, Train Loss: 0.151, Val Loss: 0.124, Train Accuracy: 0.972, Val Accuracy: 0.978
# Epoch 26/100, Train Loss: 0.138, Val Loss: 0.125, Train Accuracy: 0.975, Val Accuracy: 0.957
# Epoch 27/100, Train Loss: 0.123, Val Loss: 0.085, Train Accuracy: 0.979, Val Accuracy: 1.000
# Epoch 28/100, Train Loss: 0.122, Val Loss: 0.070, Train Accuracy: 0.978, Val Accuracy: 0.978
# Epoch 29/100, Train Loss: 0.111, Val Loss: 0.123, Train Accuracy: 0.974, Val Accuracy: 0.957
# Epoch 30/100, Train Loss: 0.100, Val Loss: 0.098, Train Accuracy: 0.990, Val Accuracy: 0.978
# Epoch 31/100, Train Loss: 0.100, Val Loss: 0.062, Train Accuracy: 0.984, Val Accuracy: 0.978
# Epoch 32/100, Train Loss: 0.083, Val Loss: 0.054, Train Accuracy: 0.991, Val Accuracy: 1.000
# Epoch 33/100, Train Loss: 0.078, Val Loss: 0.070, Train Accuracy: 0.992, Val Accuracy: 0.978
# Epoch 34/100, Train Loss: 0.082, Val Loss: 0.051, Train Accuracy: 0.984, Val Accuracy: 1.000
# Epoch 35/100, Train Loss: 0.071, Val Loss: 0.051, Train Accuracy: 0.989, Val Accuracy: 1.000
# Epoch 36/100, Train Loss: 0.061, Val Loss: 0.048, Train Accuracy: 0.990, Val Accuracy: 1.000
# Epoch 37/100, Train Loss: 0.066, Val Loss: 0.046, Train Accuracy: 0.990, Val Accuracy: 1.000
# Epoch 38/100, Train Loss: 0.060, Val Loss: 0.051, Train Accuracy: 0.991, Val Accuracy: 1.000
# Epoch 39/100, Train Loss: 0.051, Val Loss: 0.049, Train Accuracy: 0.995, Val Accuracy: 0.978
# Epoch 40/100, Train Loss: 0.053, Val Loss: 0.045, Train Accuracy: 0.994, Val Accuracy: 0.978
# Epoch 41/100, Train Loss: 0.054, Val Loss: 0.058, Train Accuracy: 0.993, Val Accuracy: 0.978
# Epoch 42/100, Train Loss: 0.049, Val Loss: 0.060, Train Accuracy: 0.996, Val Accuracy: 0.978
# Epoch 43/100, Train Loss: 0.050, Val Loss: 0.080, Train Accuracy: 0.996, Val Accuracy: 0.978
# Epoch 44/100, Train Loss: 0.049, Val Loss: 0.038, Train Accuracy: 0.995, Val Accuracy: 1.000
# Epoch 45/100, Train Loss: 0.055, Val Loss: 0.039, Train Accuracy: 0.990, Val Accuracy: 1.000
# Epoch 46/100, Train Loss: 0.050, Val Loss: 0.042, Train Accuracy: 0.995, Val Accuracy: 1.000
# Epoch 47/100, Train Loss: 0.039, Val Loss: 0.054, Train Accuracy: 0.996, Val Accuracy: 0.978
# Epoch 48/100, Train Loss: 0.035, Val Loss: 0.037, Train Accuracy: 0.999, Val Accuracy: 1.000
# Epoch 49/100, Train Loss: 0.036, Val Loss: 0.038, Train Accuracy: 0.996, Val Accuracy: 1.000
# Epoch 50/100, Train Loss: 0.034, Val Loss: 0.090, Train Accuracy: 0.998, Val Accuracy: 0.978
# Epoch 51/100, Train Loss: 0.047, Val Loss: 0.041, Train Accuracy: 0.993, Val Accuracy: 0.978
# Epoch 52/100, Train Loss: 0.057, Val Loss: 0.048, Train Accuracy: 0.987, Val Accuracy: 0.978
# Epoch 53/100, Train Loss: 0.034, Val Loss: 0.064, Train Accuracy: 0.997, Val Accuracy: 0.978
# Epoch 54/100, Train Loss: 0.034, Val Loss: 0.037, Train Accuracy: 0.993, Val Accuracy: 1.000
# Epoch 55/100, Train Loss: 0.032, Val Loss: 0.043, Train Accuracy: 0.998, Val Accuracy: 0.978
# Epoch 56/100, Train Loss: 0.029, Val Loss: 0.055, Train Accuracy: 0.999, Val Accuracy: 0.978
# Epoch 57/100, Train Loss: 0.028, Val Loss: 0.042, Train Accuracy: 0.999, Val Accuracy: 0.978
# Epoch 58/100, Train Loss: 0.035, Val Loss: 0.133, Train Accuracy: 0.997, Val Accuracy: 0.957
# Epoch 59/100, Train Loss: 0.038, Val Loss: 0.040, Train Accuracy: 0.998, Val Accuracy: 0.978
# Epoch 60/100, Train Loss: 0.031, Val Loss: 0.099, Train Accuracy: 0.996, Val Accuracy: 0.978
# Epoch 61/100, Train Loss: 0.022, Val Loss: 0.037, Train Accuracy: 1.000, Val Accuracy: 1.000
# Epoch 62/100, Train Loss: 0.025, Val Loss: 0.051, Train Accuracy: 0.999, Val Accuracy: 0.978
# Epoch 63/100, Train Loss: 0.023, Val Loss: 0.051, Train Accuracy: 0.999, Val Accuracy: 0.978
# Epoch 64/100, Train Loss: 0.026, Val Loss: 0.046, Train Accuracy: 0.999, Val Accuracy: 0.978
# Early stopping
#
# Total Training Time: 6.45 seconds
# Test Loss: 0.167, Test Accuracy: 0.929
#
# Matthews Correlation Coefficient: 0.860
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.97      0.93        91
#          1.0       0.96      0.89      0.93        91
#
#     accuracy                           0.93       182
#    macro avg       0.93      0.93      0.93       182
# weighted avg       0.93      0.93      0.93       182
#
#
# Confusion Matrix:

# %%
device, model, criterion, optimizer = declare_model(model_llm='llama2', kernel_size=KERNEL_SIZE, learning_rate=LEARNING_RATE)
training(train_loader, val_loader, model, criterion, optimizer, device, epochs=EPOCH, patience=PATIENCE, min_delta=MIN_DELTA)
evaluate(test_loader, model, criterion, optimizer, device)
# Out:
# Training CNN with Embedding llama2
#
# CNN Architecture:
# CNNModel(
#   (embedding): Embedding(2521, 4096, padding_idx=0)
#   (layer_norm): LayerNorm((4096,), eps=1e-05, elementwise_affine=True)
#   (conv1): Conv1d(4096, 128, kernel_size=(3,), stride=(1,))
#   (bn1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (maxpool): MaxPool1d(kernel_size=3, stride=3, padding=0, dilation=1, ceil_mode=False)
#   (dropout): Dropout(p=0.2, inplace=False)
#   (conv2): Conv1d(128, 64, kernel_size=(3,), stride=(1,))
#   (bn2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (global_maxpool): AdaptiveMaxPool1d(output_size=1)
#   (fc1): Linear(in_features=64, out_features=32, bias=True)
#   (fc2): Linear(in_features=32, out_features=1, bias=True)
#   (relu): ReLU()
# )
#
# Epoch 1/100, Train Loss: 0.595, Val Loss: 0.551, Train Accuracy: 0.734, Val Accuracy: 0.913
# Epoch 2/100, Train Loss: 0.487, Val Loss: 0.415, Train Accuracy: 0.851, Val Accuracy: 0.913
# Epoch 3/100, Train Loss: 0.440, Val Loss: 0.351, Train Accuracy: 0.847, Val Accuracy: 0.935
# Epoch 4/100, Train Loss: 0.385, Val Loss: 0.306, Train Accuracy: 0.904, Val Accuracy: 0.957
# Epoch 5/100, Train Loss: 0.337, Val Loss: 0.283, Train Accuracy: 0.920, Val Accuracy: 0.935
# Epoch 6/100, Train Loss: 0.293, Val Loss: 0.235, Train Accuracy: 0.940, Val Accuracy: 0.978
# Epoch 7/100, Train Loss: 0.246, Val Loss: 0.206, Train Accuracy: 0.965, Val Accuracy: 0.978
# Epoch 8/100, Train Loss: 0.223, Val Loss: 0.183, Train Accuracy: 0.965, Val Accuracy: 0.978
# Epoch 9/100, Train Loss: 0.205, Val Loss: 0.170, Train Accuracy: 0.966, Val Accuracy: 0.978
# Epoch 10/100, Train Loss: 0.178, Val Loss: 0.150, Train Accuracy: 0.979, Val Accuracy: 0.978
# Epoch 11/100, Train Loss: 0.150, Val Loss: 0.128, Train Accuracy: 0.984, Val Accuracy: 1.000
# Epoch 12/100, Train Loss: 0.129, Val Loss: 0.124, Train Accuracy: 0.989, Val Accuracy: 1.000
# Epoch 13/100, Train Loss: 0.120, Val Loss: 0.106, Train Accuracy: 0.985, Val Accuracy: 0.978
# Epoch 14/100, Train Loss: 0.103, Val Loss: 0.136, Train Accuracy: 0.998, Val Accuracy: 0.978
# Epoch 15/100, Train Loss: 0.083, Val Loss: 0.099, Train Accuracy: 0.998, Val Accuracy: 1.000
# Epoch 16/100, Train Loss: 0.078, Val Loss: 0.092, Train Accuracy: 0.998, Val Accuracy: 1.000
# Epoch 17/100, Train Loss: 0.071, Val Loss: 0.144, Train Accuracy: 0.997, Val Accuracy: 0.978
# Epoch 18/100, Train Loss: 0.059, Val Loss: 0.085, Train Accuracy: 0.998, Val Accuracy: 0.978
# Epoch 19/100, Train Loss: 0.058, Val Loss: 0.079, Train Accuracy: 0.998, Val Accuracy: 1.000
# Epoch 20/100, Train Loss: 0.053, Val Loss: 0.054, Train Accuracy: 0.999, Val Accuracy: 1.000
# Epoch 21/100, Train Loss: 0.047, Val Loss: 0.087, Train Accuracy: 0.998, Val Accuracy: 0.978
# Epoch 22/100, Train Loss: 0.038, Val Loss: 0.069, Train Accuracy: 1.000, Val Accuracy: 0.978
# Epoch 23/100, Train Loss: 0.037, Val Loss: 0.097, Train Accuracy: 1.000, Val Accuracy: 0.978
# Epoch 24/100, Train Loss: 0.036, Val Loss: 0.072, Train Accuracy: 1.000, Val Accuracy: 0.978
# Epoch 25/100, Train Loss: 0.031, Val Loss: 0.052, Train Accuracy: 1.000, Val Accuracy: 1.000
# Epoch 26/100, Train Loss: 0.028, Val Loss: 0.046, Train Accuracy: 1.000, Val Accuracy: 1.000
# Epoch 27/100, Train Loss: 0.024, Val Loss: 0.049, Train Accuracy: 1.000, Val Accuracy: 1.000
# Epoch 28/100, Train Loss: 0.023, Val Loss: 0.064, Train Accuracy: 1.000, Val Accuracy: 0.978
# Epoch 29/100, Train Loss: 0.021, Val Loss: 0.053, Train Accuracy: 1.000, Val Accuracy: 0.978
# Epoch 30/100, Train Loss: 0.021, Val Loss: 0.058, Train Accuracy: 1.000, Val Accuracy: 0.978
# Epoch 31/100, Train Loss: 0.021, Val Loss: 0.050, Train Accuracy: 1.000, Val Accuracy: 1.000
# Epoch 32/100, Train Loss: 0.024, Val Loss: 0.073, Train Accuracy: 1.000, Val Accuracy: 0.978
# Epoch 33/100, Train Loss: 0.024, Val Loss: 0.050, Train Accuracy: 0.999, Val Accuracy: 0.978
# Epoch 34/100, Train Loss: 0.021, Val Loss: 0.071, Train Accuracy: 1.000, Val Accuracy: 0.978
# Epoch 35/100, Train Loss: 0.021, Val Loss: 0.065, Train Accuracy: 1.000, Val Accuracy: 0.978
# Epoch 36/100, Train Loss: 0.018, Val Loss: 0.047, Train Accuracy: 1.000, Val Accuracy: 1.000
# Early stopping
#
# Total Training Time: 3.88 seconds
# Test Loss: 0.108, Test Accuracy: 0.967
#
# Matthews Correlation Coefficient: 0.934
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.96      0.97        91
#          1.0       0.96      0.98      0.97        91
#
#     accuracy                           0.97       182
#    macro avg       0.97      0.97      0.97       182
# weighted avg       0.97      0.97      0.97       182
#
#
# Confusion Matrix:
