# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import time

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import matthews_corrcoef
from transformers import get_linear_schedule_with_warmup

import torch
import torch.nn as nn
import torch.optim as optim
# Out:
# 2024-12-05 08:30:36.143477: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-12-05 08:30:36.167255: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-12-05 08:30:36.173689: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-05 08:30:36.194522: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-12-05 08:30:37.553236: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
df = pd.read_excel('/home/basilmusyaffa19/Skripsi Basil/Dataset/FIX/clean_SMS_22112024.xlsx', engine='openpyxl')
df
# Out:
#                                                    teks  label
# 0     promo beli paket flash mulai aplikasi my telko...      1
# 1     gb hari rp ribu spesial buat kamu pilih aktif ...      1
# 2     plg hormat sisa kuota flash download aplikasi ...      1
# 3     mohon hormat sisa kuota flash download aplikas...      1
# 4     hari rp ribu khusus buat kamu pilih aktif seka...      1
# ...                                                 ...    ...
# 1138             yooo sama sama aku umum kelompok kelas      0
# 1139         pernah tulis cadar belum pikir warna jeans      0
# 1140                                       bu mau kirim      0
# 1141                  berangkat pagi mau tunai transfer      0
# 1142                         berapa nomor bri atas nama      0
#
# [1143 rows x 2 columns]

# %%
print("Jumlah data sebelum:", len(df))

# Menghapus data kosong
df = df.replace('', np.nan).dropna()
# Hapus NaN
df = df.dropna(subset=['teks'])
# Menghapus nilai float
df = df[~df['teks'].apply(lambda x: isinstance(x, float))]
# Menghapus semua baris yang duplikat
df = df.drop_duplicates(subset=['teks'], keep='first')

print("Jumlah data setelah:", len(df))
# Out:
# Jumlah data sebelum: 1143
# Jumlah data setelah: 1138

# %%
label = df['label'].value_counts()
print(label)
# Out:
# label
# 1    571
# 0    567
# Name: count, dtype: int64

# %%
import pickle

def padding_texts(df):
    with open('/home/basilmusyaffa19/Skripsi Basil/Embedding Matrix/Dataset Indo/indo_keras_tokenizer.pickle', 'rb') as handle:
        keras_tokenizer = pickle.load(handle)

    sequences = keras_tokenizer.texts_to_sequences(df['teks'])
    max_length = max(len(seq) for seq in sequences)
    padded_sequences = pad_sequences(sequences, maxlen=max_length)
    vocab_size = len(keras_tokenizer.word_index) + 1
    
    return padded_sequences, vocab_size

# %%
def split_data(padded_sequences, labels, test_size, val_size, random_state=42):
    X_train, X_temp, y_train, y_temp = train_test_split(
        padded_sequences,
        labels,
        test_size=test_size,
        stratify=labels,
        random_state=random_state,
    )

    X_test, X_val, y_test, y_val = train_test_split(
        X_temp,
        y_temp,
        test_size=val_size,
        stratify=y_temp,
        random_state=random_state,
    )
    
    print(f'X_train Shape: {X_train.shape}')
    print(f'X_val Shape: {X_val.shape}')
    print(f'X_test Shape: {X_test.shape}')
    print('')
    
    print(f'y_train Class: {y_train.nunique()}')
    print(f'y_val Class: {y_val.nunique()}')
    print(f'y_test Class: {y_test.nunique()}')
    print('')
    
    return X_train, X_val, X_test, y_train, y_val, y_test

# %%
def create_data_loaders(X_train, X_val, X_test, y_train, y_val, y_test, batch_size):
    y_train = torch.tensor(y_train.values, dtype=torch.float32)
    y_val = torch.tensor(y_val.values, dtype=torch.float32)
    y_test = torch.tensor(y_test.values, dtype=torch.float32)

    X_train = torch.tensor(X_train, dtype=torch.int64)
    X_val = torch.tensor(X_val, dtype=torch.int64)
    X_test = torch.tensor(X_test, dtype=torch.int64)

    train_dataset = TensorDataset(X_train, y_train)
    val_dataset = TensorDataset(X_val, y_val)
    test_dataset = TensorDataset(X_test, y_test)

    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
    
    return train_loader, val_loader, test_loader

# %%
def prepare_data_loader(df, test_size, val_size, batch_size, random_state=42):
    padded_sequences, vocab_size = padding_texts(df)
    X_train, X_val, X_test, y_train, y_val, y_test = split_data(padded_sequences, df['label'], test_size, val_size, random_state)
    train_loader, val_loader, test_loader = create_data_loaders(X_train, X_val, X_test, y_train, y_val, y_test, batch_size=batch_size)
    
    return train_loader, val_loader, test_loader, vocab_size

# %%
class CNNModel(nn.Module):
    def __init__(self, embedding_matrix, embedding_dim, kernel_size, output_dim=1):
        super(CNNModel, self).__init__()
        
        # Embedding layer dengan Layer Normalization
        self.embedding = nn.Embedding.from_pretrained(embedding_matrix, freeze=True, padding_idx=0)
        self.layer_norm = nn.LayerNorm(embedding_dim)
        
        # Conv1 block dengan Batch Normalization
        self.conv1 = nn.Conv1d(in_channels=embedding_dim, out_channels=256, kernel_size=kernel_size)
        self.bn1 = nn.BatchNorm1d(256)
        
        # Conv2 block dengan Batch Normalization
        self.conv2 = nn.Conv1d(in_channels=256, out_channels=128, kernel_size=kernel_size)
        self.bn2 = nn.BatchNorm1d(128)
        
        # Conv3 block dengan Batch Normalization (Tambahan)
        self.conv3 = nn.Conv1d(in_channels=128, out_channels=64, kernel_size=kernel_size)
        self.bn3 = nn.BatchNorm1d(64)
        
        self.maxpool = nn.MaxPool1d(kernel_size=kernel_size)
        self.global_maxpool = nn.AdaptiveMaxPool1d(1)
        self.dropout = nn.Dropout(p=0.2)
        
        # Fully connected layers
        self.fc1 = nn.Linear(64, 32)
        self.fc2 = nn.Linear(32, output_dim)
        self.relu = nn.ReLU()
        
    def forward(self, x):
        # Embedding layer dengan Layer Normalization
        x = self.embedding(x)
        x = self.layer_norm(x)
        x = x.permute(0, 2, 1)
        
        # Conv1 block
        x = self.conv1(x)
        x = self.bn1(x)
        x = self.relu(x)
        x = self.maxpool(x)
        x = self.dropout(x)
        
        # Conv2 block
        x = self.conv2(x)
        x = self.bn2(x)
        x = self.relu(x)
        x = self.dropout(x)
        
        # Conv3 block
        x = self.conv3(x)
        x = self.bn3(x)
        x = self.relu(x)
        
        # Global pooling
        x = self.global_maxpool(x).squeeze(-1)
        x = self.dropout(x)
        
        # Fully connected layers
        x = self.relu(self.fc1(x))
        x = self.dropout(x)
        x = torch.sigmoid(self.fc2(x))
        
        return x.squeeze(-1)

# %%
class EarlyStopping:
    def __init__(self, patience, min_delta):
        self.patience = patience
        self.min_delta = min_delta
        self.counter = 0
        self.best_loss = None
        self.early_stop = False

    def __call__(self, val_loss):
        if self.best_loss is None:
            self.best_loss = val_loss
        elif val_loss < self.best_loss - self.min_delta: # Jika ada improvement
            self.best_loss = val_loss
            self.counter = 0
        else:  # Jika tidak ada improvement
            self.counter += 1
            if self.counter >= self.patience:
                self.early_stop = True

# %%
def prepare_embedding_matrix(model):
    paths = {
        'gpt2': '/home/basilmusyaffa19/Skripsi Basil/Embedding Matrix/Dataset Indo/Hasil Embedding/21 Nov/embedding_matrix_gpt2_1024D_21112024.npy',
        'llama2': '/home/basilmusyaffa19/Skripsi Basil/Embedding Matrix/Dataset Indo/Hasil Embedding/21 Nov/embedding_matrix_llama2_4096D_21112024.npy',
        'XLM-R': '/home/basilmusyaffa19/Skripsi Basil/Embedding Matrix/Dataset Indo/Hasil Embedding/21 Nov/embedding_matrix_XLMroBERTaLarge_1024D_21112024.npy',
        'mT5': '/home/basilmusyaffa19/Skripsi Basil/Embedding Matrix/Dataset Indo/Hasil Embedding/21 Nov/embedding_matrix_mt5Large_1024D_21112024.npy',
        'gloveWiki': '/home/basilmusyaffa19/Skripsi Basil/Embedding Matrix/Dataset Indo/Hasil Embedding/21 Nov/embedding_matrix_gloveWiki_50D_21112024.npy',
        'indoBERT': '/home/basilmusyaffa19/Skripsi Basil/Embedding Matrix/Dataset Indo/Hasil Embedding/21 Nov/embedding_matrix_indoBERTLarge_1024D_21112024.npy',
    }
    
    path = paths.get(model)
    
    if path:
        embedding_matrix = np.load(path)
        embedding_dim = embedding_matrix.shape[1]
        embedding_matrix = torch.tensor(embedding_matrix, dtype=torch.float32)
        return embedding_matrix, embedding_dim
    else:
        raise ValueError(f"Model '{model}' is not recognized")

def declare_model(model_llm, kernel_size, learning_rate):
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    print(f"Training CNN with Embedding {model_llm} \n")
    embedding_matrix, embedding_dim = prepare_embedding_matrix(model=model_llm)
    model = CNNModel(embedding_matrix, embedding_dim, kernel_size)
    model.to(device)
    criterion = nn.BCELoss()
    optimizer = optim.Adam(model.parameters(), 
                           lr=learning_rate,
                           weight_decay=1e-4)
    
    print('CNN Architecture:')
    print(model)
    print('')
    
    return device, model, criterion, optimizer

# %%
def binary_accuracy(y_pred, y_true):
    y_pred_tags = (y_pred > 0.5).long()
    correct_results_sum = (y_pred_tags == y_true).sum().float()
    acc = correct_results_sum / y_true.shape[0]
    return acc

def training(train_loader, val_loader, model, criterion, optimizer, device, epochs, patience, min_delta):
    torch.cuda.empty_cache()
    
    total_start_time = time.time()
    early_stopping = EarlyStopping(patience=patience, min_delta=min_delta)
    
    num_training_steps = epochs * len(train_loader)
    
    scheduler = get_linear_schedule_with_warmup(
        optimizer,
        num_warmup_steps=0,
        num_training_steps=num_training_steps
    )
    
    train_losses = []
    val_losses = []
    
    for epoch in range(epochs):
        model.train()
        train_loss_final = 0.0
        train_accuracy_final = 0.0
        for X_train, y_train in train_loader:
            X_train, y_train = X_train.to(device), y_train.to(device)
            optimizer.zero_grad()
            
            y_train_pred = model(X_train)
            train_loss = criterion(y_train_pred, y_train.float())
            train_accuracy = binary_accuracy(y_train_pred, y_train)
            
            train_loss.backward()
            optimizer.step()
            scheduler.step()
            
            train_loss_final += train_loss.item()
            train_accuracy_final += train_accuracy.item()
        avg_train_loss = train_loss_final / len(train_loader)
        avg_train_accuracy = train_accuracy_final / len(train_loader)
        train_losses.append(avg_train_loss)
        
        model.eval()
        val_loss_final = 0.0
        val_accuracy_final = 0.0
        with torch.no_grad():
            for X_val, y_val in val_loader:
                X_val, y_val = X_val.to(device), y_val.to(device)
                
                y_val_pred = model(X_val)
                val_loss = criterion(y_val_pred, y_val.float())
                val_accuracy = binary_accuracy(y_val_pred, y_val)
                
                val_loss_final += val_loss.item()
                val_accuracy_final += val_accuracy.item()
            avg_val_loss = val_loss_final / len(val_loader)
            avg_val_accuracy = val_accuracy_final / len(val_loader)
            val_losses.append(avg_val_loss)

        print(f'Epoch {epoch+1}/{epochs}, Train Loss: {avg_train_loss:.3f}, Val Loss: {avg_val_loss:.3f}, Train Accuracy: {avg_train_accuracy:.3f}, Val Accuracy: {avg_val_accuracy:.3f}')
    
        early_stopping(avg_val_loss)
    
        if early_stopping.early_stop:
            print("Early stopping")
            break
            
    total_end_time = time.time()
    total_time = total_end_time - total_start_time
    print(f'\nTotal Training Time: {total_time:.2f} seconds')
    
    # Plot learning curves
    plt.figure(figsize=(10, 5))
    plt.plot(train_losses, label='Train Loss')
    plt.plot(val_losses, label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Learning Curve')
    plt.legend()
    plt.show()

# %%
def evaluate(test_loader, model, criterion, optimizer, device):
    model.eval()
    test_loss_final = 0.0
    test_accuracy_final = 0.0
    y_pred_list = []
    y_test_list = []
    for X_test, y_test in test_loader:
        X_test, y_test = X_test.to(device), y_test.to(device)
        
        y_test_pred = model(X_test)
        test_loss = criterion(y_test_pred, y_test.float())
        test_accuracy = binary_accuracy(y_test_pred, y_test)
        
        test_loss_final += test_loss.item()
        test_accuracy_final += test_accuracy.item()
        
        y_pred_tags = (y_test_pred > 0.5).long()
        y_pred_list.append(y_pred_tags.cpu().numpy())
        y_test_list.append(y_test.cpu().numpy())
        
    avg_test_loss = test_loss_final / len(test_loader)
    avg_test_accuracy = test_accuracy_final / len(test_loader)
    
    print(f'Test Loss: {avg_test_loss:.3f}, Test Accuracy: {avg_test_accuracy:.3f}')
    print('')
    
    y_pred_list = np.concatenate([a.squeeze() for a in y_pred_list]).tolist()
    y_test_list = np.concatenate([a.squeeze() for a in y_test_list]).tolist()
    
    mcc = matthews_corrcoef(y_test_list, y_pred_list)
    print(f'Matthews Correlation Coefficient: {mcc:.3f}')
    print('')
    
    cm = confusion_matrix(y_test_list, y_pred_list)
    print('Classification Report:')
    print(classification_report(y_test_list, y_pred_list))
    print('')
    
    print('Confusion Matrix:')
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Predicted 0', 'Predicted 1'], yticklabels=['Actual 0', 'Actual 1'])
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.title('Confusion Matrix')
    plt.show()

# %%
LEARNING_RATE = 1e-4
EPOCH = 100
BATCH_SIZE = 64
KERNEL_SIZE = 3
PATIENCE = 10
MIN_DELTA= 1e-3

# %%
train_loader, val_loader, test_loader, vocab_size = prepare_data_loader(df, test_size=0.2, val_size=0.2, batch_size=BATCH_SIZE)
# Out:
# X_train Shape: (910, 44)
# X_val Shape: (46, 44)
# X_test Shape: (182, 44)
#
# y_train Class: 2
# y_val Class: 2
# y_test Class: 2

# %%
device, model, criterion, optimizer = declare_model(model_llm='gloveWiki', kernel_size=KERNEL_SIZE, learning_rate=LEARNING_RATE)
training(train_loader, val_loader, model, criterion, optimizer, device, epochs=EPOCH, patience=PATIENCE, min_delta=MIN_DELTA)
evaluate(test_loader, model, criterion, optimizer, device)
# Out:
# Training CNN with Embedding gloveWiki
#
# CNN Architecture:
# CNNModel(
#   (embedding): Embedding(2521, 50, padding_idx=0)
#   (layer_norm): LayerNorm((50,), eps=1e-05, elementwise_affine=True)
#   (conv1): Conv1d(50, 256, kernel_size=(3,), stride=(1,))
#   (bn1): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv2): Conv1d(256, 128, kernel_size=(3,), stride=(1,))
#   (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv3): Conv1d(128, 64, kernel_size=(3,), stride=(1,))
#   (bn3): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (maxpool): MaxPool1d(kernel_size=3, stride=3, padding=0, dilation=1, ceil_mode=False)
#   (global_maxpool): AdaptiveMaxPool1d(output_size=1)
#   (dropout): Dropout(p=0.2, inplace=False)
#   (fc1): Linear(in_features=64, out_features=32, bias=True)
#   (fc2): Linear(in_features=32, out_features=1, bias=True)
#   (relu): ReLU()
# )
#
# Epoch 1/100, Train Loss: 0.600, Val Loss: 0.608, Train Accuracy: 0.658, Val Accuracy: 0.935
# Epoch 2/100, Train Loss: 0.552, Val Loss: 0.463, Train Accuracy: 0.764, Val Accuracy: 0.957
# Epoch 3/100, Train Loss: 0.494, Val Loss: 0.376, Train Accuracy: 0.837, Val Accuracy: 0.978
# Epoch 4/100, Train Loss: 0.443, Val Loss: 0.337, Train Accuracy: 0.878, Val Accuracy: 0.957
# Epoch 5/100, Train Loss: 0.428, Val Loss: 0.298, Train Accuracy: 0.875, Val Accuracy: 0.978
# Epoch 6/100, Train Loss: 0.394, Val Loss: 0.265, Train Accuracy: 0.900, Val Accuracy: 0.957
# Epoch 7/100, Train Loss: 0.358, Val Loss: 0.246, Train Accuracy: 0.897, Val Accuracy: 0.957
# Epoch 8/100, Train Loss: 0.352, Val Loss: 0.229, Train Accuracy: 0.899, Val Accuracy: 0.935
# Epoch 9/100, Train Loss: 0.320, Val Loss: 0.206, Train Accuracy: 0.917, Val Accuracy: 0.978
# Epoch 10/100, Train Loss: 0.309, Val Loss: 0.197, Train Accuracy: 0.910, Val Accuracy: 0.978
# Epoch 11/100, Train Loss: 0.283, Val Loss: 0.184, Train Accuracy: 0.914, Val Accuracy: 1.000
# Epoch 12/100, Train Loss: 0.269, Val Loss: 0.174, Train Accuracy: 0.930, Val Accuracy: 0.957
# Epoch 13/100, Train Loss: 0.252, Val Loss: 0.160, Train Accuracy: 0.926, Val Accuracy: 1.000
# Epoch 14/100, Train Loss: 0.241, Val Loss: 0.151, Train Accuracy: 0.930, Val Accuracy: 0.978
# Epoch 15/100, Train Loss: 0.221, Val Loss: 0.144, Train Accuracy: 0.935, Val Accuracy: 0.978
# Epoch 16/100, Train Loss: 0.222, Val Loss: 0.135, Train Accuracy: 0.932, Val Accuracy: 0.978
# Epoch 17/100, Train Loss: 0.199, Val Loss: 0.130, Train Accuracy: 0.954, Val Accuracy: 0.978
# Epoch 18/100, Train Loss: 0.223, Val Loss: 0.126, Train Accuracy: 0.936, Val Accuracy: 0.978
Train Accuracy: 1.000, Val Accuracy: 1.000
# Epoch 98/100, Train Loss: 0.023, Val Loss: 0.034, Train Accuracy: 0.999, Val Accuracy: 1.000
# Epoch 99/100, Train Loss: 0.021, Val Loss: 0.033, Train Accuracy: 0.998, Val Accuracy: 1.000
# Early stopping
#
# Total Training Time: 8.82 seconds
# Test Loss: 0.157, Test Accuracy: 0.952
#
# Matthews Correlation Coefficient: 0.901
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.95      0.95        91
#          1.0       0.95      0.96      0.95        91
#
#     accuracy                           0.95       182
#    macro avg       0.95      0.95      0.95       182
# weighted avg       0.95      0.95      0.95       182
#
#
# Confusion Matrix:

# %%
device, model, criterion, optimizer = declare_model(model_llm='indoBERT', kernel_size=KERNEL_SIZE, learning_rate=LEARNING_RATE)
training(train_loader, val_loader, model, criterion, optimizer, device, epochs=EPOCH, patience=PATIENCE, min_delta=MIN_DELTA)
evaluate(test_loader, model, criterion, optimizer, device)
# Out:
# Training CNN with Embedding indoBERT
#
# CNN Architecture:
# CNNModel(
#   (embedding): Embedding(2521, 1024, padding_idx=0)
#   (layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#   (conv1): Conv1d(1024, 256, kernel_size=(3,), stride=(1,))
#   (bn1): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv2): Conv1d(256, 128, kernel_size=(3,), stride=(1,))
#   (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv3): Conv1d(128, 64, kernel_size=(3,), stride=(1,))
#   (bn3): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (maxpool): MaxPool1d(kernel_size=3, stride=3, padding=0, dilation=1, ceil_mode=False)
#   (global_maxpool): AdaptiveMaxPool1d(output_size=1)
#   (dropout): Dropout(p=0.2, inplace=False)
#   (fc1): Linear(in_features=64, out_features=32, bias=True)
#   (fc2): Linear(in_features=32, out_features=1, bias=True)
#   (relu): ReLU()
# )
#
# Epoch 1/100, Train Loss: 0.625, Val Loss: 0.608, Train Accuracy: 0.691, Val Accuracy: 0.848
# Epoch 2/100, Train Loss: 0.537, Val Loss: 0.503, Train Accuracy: 0.794, Val Accuracy: 0.826
# Epoch 3/100, Train Loss: 0.514, Val Loss: 0.451, Train Accuracy: 0.818, Val Accuracy: 0.913
# Epoch 4/100, Train Loss: 0.511, Val Loss: 0.430, Train Accuracy: 0.817, Val Accuracy: 0.913
# Epoch 5/100, Train Loss: 0.490, Val Loss: 0.405, Train Accuracy: 0.808, Val Accuracy: 0.935
# Epoch 6/100, Train Loss: 0.489, Val Loss: 0.393, Train Accuracy: 0.813, Val Accuracy: 0.935
# Epoch 7/100, Train Loss: 0.474, Val Loss: 0.388, Train Accuracy: 0.828, Val Accuracy: 0.935
# Epoch 8/100, Train Loss: 0.468, Val Loss: 0.374, Train Accuracy: 0.833, Val Accuracy: 0.935
# Epoch 9/100, Train Loss: 0.469, Val Loss: 0.380, Train Accuracy: 0.819, Val Accuracy: 0.935
# Epoch 10/100, Train Loss: 0.462, Val Loss: 0.361, Train Accuracy: 0.829, Val Accuracy: 0.935
# Epoch 11/100, Train Loss: 0.458, Val Loss: 0.346, Train Accuracy: 0.836, Val Accuracy: 0.935
# Epoch 12/100, Train Loss: 0.442, Val Loss: 0.350, Train Accuracy: 0.833, Val Accuracy: 0.935
# Epoch 13/100, Train Loss: 0.448, Val Loss: 0.346, Train Accuracy: 0.833, Val Accuracy: 0.935
# Epoch 14/100, Train Loss: 0.436, Val Loss: 0.335, Train Accuracy: 0.831, Val Accuracy: 0.935
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.84      0.75      0.79        91
#          1.0       0.77      0.86      0.81        91
#
#     accuracy                           0.80       182
#    macro avg       0.81      0.80      0.80       182
# weighted avg       0.81      0.80      0.80       182
#
#
# Confusion Matrix:

# %%
device, model, criterion, optimizer = declare_model(model_llm='XLM-R', kernel_size=KERNEL_SIZE, learning_rate=LEARNING_RATE)
training(train_loader, val_loader, model, criterion, optimizer, device, epochs=EPOCH, patience=PATIENCE, min_delta=MIN_DELTA)
evaluate(test_loader, model, criterion, optimizer, device)
# Out:
# Training CNN with Embedding XLM-R
#
# CNN Architecture:
# CNNModel(
#   (embedding): Embedding(2521, 1024, padding_idx=0)
#   (layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#   (conv1): Conv1d(1024, 256, kernel_size=(3,), stride=(1,))
#   (bn1): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv2): Conv1d(256, 128, kernel_size=(3,), stride=(1,))
#   (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv3): Conv1d(128, 64, kernel_size=(3,), stride=(1,))
#   (bn3): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (maxpool): MaxPool1d(kernel_size=3, stride=3, padding=0, dilation=1, ceil_mode=False)
#   (global_maxpool): AdaptiveMaxPool1d(output_size=1)
#   (dropout): Dropout(p=0.2, inplace=False)
#   (fc1): Linear(in_features=64, out_features=32, bias=True)
#   (fc2): Linear(in_features=32, out_features=1, bias=True)
#   (relu): ReLU()
# )
#
# Epoch 1/100, Train Loss: 0.622, Val Loss: 0.672, Train Accuracy: 0.681, Val Accuracy: 0.500
# Epoch 2/100, Train Loss: 0.561, Val Loss: 0.585, Train Accuracy: 0.764, Val Accuracy: 0.848
# Epoch 3/100, Train Loss: 0.532, Val Loss: 0.498, Train Accuracy: 0.800, Val Accuracy: 0.935
# Epoch 4/100, Train Loss: 0.513, Val Loss: 0.453, Train Accuracy: 0.804, Val Accuracy: 0.935
# Epoch 5/100, Train Loss: 0.481, Val Loss: 0.431, Train Accuracy: 0.838, Val Accuracy: 0.935
# Epoch 6/100, Train Loss: 0.481, Val Loss: 0.379, Train Accuracy: 0.828, Val Accuracy: 0.935
# Epoch 7/100, Train Loss: 0.432, Val Loss: 0.401, Train Accuracy: 0.848, Val Accuracy: 0.957
# Epoch 8/100, Train Loss: 0.411, Val Loss: 0.348, Train Accuracy: 0.878, Val Accuracy: 0.935
# Epoch 9/100, Train Loss: 0.384, Val Loss: 0.353, Train Accuracy: 0.867, Val Accuracy: 0.957
# Epoch 10/100, Train Loss: 0.363, Val Loss: 0.321, Train Accuracy: 0.888, Val Accuracy: 0.957
# Epoch 11/100, Train Loss: 0.322, Val Loss: 0.325, Train Accuracy: 0.918, Val Accuracy: 0.891
# Epoch 12/100, Train Loss: 0.297, Val Loss: 0.259, Train Accuracy: 0.934, Val Accuracy: 0.957
# Epoch 13/100, Train Loss: 0.278, Val Loss: 0.235, Train Accuracy: 0.931, Val Accuracy: 0.978
# Epoch 14/100, Train Loss: 0.251, Val Loss: 0.209, Train Accuracy: 0.944, Val Accuracy: 0.978
# Epoch 15/100, Train Loss: 0.236, Val Loss: 0.321, Train Accuracy: 0.945, Val Accuracy: 0.870
# Epoch 16/100, Train Loss: 0.216, Val Loss: 0.252, Train Accuracy: 0.951, Val Accuracy: 0.913
# Epoch 43/100, Train Loss: 0.027, Val Loss: 0.073, Train Accuracy: 0.998, Val Accuracy: 1.000
# Epoch 44/100, Train Loss: 0.024, Val Loss: 0.049, Train Accuracy: 0.999, Val Accuracy: 1.000
# Epoch 45/100, Train Loss: 0.030, Val Loss: 0.167, Train Accuracy: 0.992, Val Accuracy: 0.913
# Epoch 46/100, Train Loss: 0.028, Val Loss: 0.059, Train Accuracy: 0.998, Val Accuracy: 1.000
# Epoch 47/100, Train Loss: 0.028, Val Loss: 0.095, Train Accuracy: 0.997, Val Accuracy: 0.978
# Epoch 48/100, Train Loss: 0.024, Val Loss: 0.090, Train Accuracy: 0.999, Val Accuracy: 0.978
# Epoch 49/100, Train Loss: 0.024, Val Loss: 0.044, Train Accuracy: 1.000, Val Accuracy: 1.000
# Epoch 50/100, Train Loss: 0.021, Val Loss: 0.109, Train Accuracy: 0.999, Val Accuracy: 0.935
# Epoch 51/100, Train Loss: 0.023, Val Loss: 0.060, Train Accuracy: 0.999, Val Accuracy: 1.000
# Epoch 52/100, Train Loss: 0.023, Val Loss: 0.045, Train Accuracy: 0.998, Val Accuracy: 1.000
# Epoch 53/100, Train Loss: 0.021, Val Loss: 0.114, Train Accuracy: 1.000, Val Accuracy: 0.957
# Epoch 54/100, Train Loss: 0.021, Val Loss: 0.080, Train Accuracy: 1.000, Val Accuracy: 0.978
# Epoch 55/100, Train Loss: 0.019, Val Loss: 0.063, Train Accuracy: 0.999, Val Accuracy: 0.978
# Epoch 56/100, Train Loss: 0.017, Val Loss: 0.049, Train Accuracy: 0.999, Val Accuracy: 1.000
# Epoch 57/100, Train Loss: 0.018, Val Loss: 0.133, Train Accuracy: 0.999, Val Accuracy: 0.978
# Epoch 58/100, Train Loss: 0.017, Val Loss: 0.043, Train Accuracy: 0.999, Val Accuracy: 1.000
# Epoch 59/100, Train Loss: 0.017, Val Loss: 0.124, Train Accuracy: 0.998, Val Accuracy: 0.957
# Early stopping
#
# Total Training Time: 7.43 seconds
# Test Loss: 0.355, Test Accuracy: 0.894
#
# Matthews Correlation Coefficient: 0.802
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.84      0.98      0.90        91
#          1.0       0.97      0.81      0.89        91
#
#     accuracy                           0.90       182
#    macro avg       0.91      0.90      0.89       182
# weighted avg       0.91      0.90      0.89       182
#
#
# Confusion Matrix:

# %%
device, model, criterion, optimizer = declare_model(model_llm='mT5', kernel_size=KERNEL_SIZE, learning_rate=LEARNING_RATE)
training(train_loader, val_loader, model, criterion, optimizer, device, epochs=EPOCH, patience=PATIENCE, min_delta=MIN_DELTA)
evaluate(test_loader, model, criterion, optimizer, device)
# Out:
# Training CNN with Embedding mT5
#
# CNN Architecture:
# CNNModel(
#   (embedding): Embedding(2521, 1024, padding_idx=0)
#   (layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#   (conv1): Conv1d(1024, 256, kernel_size=(3,), stride=(1,))
#   (bn1): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv2): Conv1d(256, 128, kernel_size=(3,), stride=(1,))
#   (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv3): Conv1d(128, 64, kernel_size=(3,), stride=(1,))
#   (bn3): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (maxpool): MaxPool1d(kernel_size=3, stride=3, padding=0, dilation=1, ceil_mode=False)
#   (global_maxpool): AdaptiveMaxPool1d(output_size=1)
#   (dropout): Dropout(p=0.2, inplace=False)
#   (f
Train Accuracy: 1.000, Val Accuracy: 1.000
# Epoch 27/100, Train Loss: 0.032, Val Loss: 0.053, Train Accuracy: 1.000, Val Accuracy: 0.978
# Epoch 28/100, Train Loss: 0.029, Val Loss: 0.069, Train Accuracy: 1.000, Val Accuracy: 0.978
# Epoch 29/100, Train Loss: 0.028, Val Loss: 0.035, Train Accuracy: 1.000, Val Accuracy: 1.000
# Epoch 30/100, Train Loss: 0.025, Val Loss: 0.071, Train Accuracy: 1.000, Val Accuracy: 0.978
# Epoch 31/100, Train Loss: 0.022, Val Loss: 0.055, Train Accuracy: 1.000, Val Accuracy: 0.978
# Epoch 32/100, Train Loss: 0.021, Val Loss: 0.045, Train Accuracy: 1.000, Val Accuracy: 1.000
# Epoch 33/100, Train Loss: 0.019, Val Loss: 0.061, Train Accuracy: 1.000, Val Accuracy: 0.978
# Epoch 34/100, Train Loss: 0.018, Val Loss: 0.043, Train Accuracy: 1.000, Val Accuracy: 1.000
# Epoch 35/100, Train Loss: 0.017, Val Loss: 0.046, Train Accuracy: 1.000, Val Accuracy: 1.000
# Epoch 36/100, Train Loss: 0.017, Val Loss: 0.076, Train Accuracy: 1.000, Val Accuracy: 0.957
# Epoch 37/100, Train Loss: 0.016, Val Loss: 0.027, Train Accuracy: 1.000, Val Accuracy: 1.000
# Epoch 38/100, Train Loss: 0.015, Val Loss: 0.072, Train Accuracy: 1.000, Val Accuracy: 0.957
# Epoch 39/100, Train Loss: 0.015, Val Loss: 0.033, Train Accuracy: 1.000, Val Accuracy: 1.000
# Epoch 40/100, Train Loss: 0.016, Val Loss: 0.050, Train Accuracy: 1.000, Val Accuracy: 0.978
# Epoch 41/100, Train Loss: 0.013, Val Loss: 0.048, Train Accuracy: 1.000, Val Accuracy: 0.978
# Epoch 42/100, Train Loss: 0.013, Val Loss: 0.067, Train Accuracy: 1.000, Val Accuracy: 0.957
# Epoch 43/100, Train Loss: 0.012, Val Loss: 0.030, Train Accuracy: 1.000, Val Accuracy: 1.000
# Epoch 44/100, Train Loss: 0.011, Val Loss: 0.040, Train Accuracy: 1.000, Val Accuracy: 1.000
# Epoch 45/100, Train Loss: 0.011, Val Loss: 0.045, Train Accuracy: 1.000, Val Accuracy: 0.978
# Epoch 46/100, Train Loss: 0.009, Val Loss: 0.032, Train Accuracy: 1.000, Val Accuracy: 1.000
# Epoch 47/100, Train Loss: 0.010, Val Loss: 0.042, Train Accuracy: 1.000, Val Accuracy: 0.978
# Early stopping
#
# Total Training Time: 3.46 seconds
# Test Loss: 0.134, Test Accuracy: 0.955
#
# Matthews Correlation Coefficient: 0.913
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.98      0.96        91
#          1.0       0.98      0.93      0.96        91
#
#     accuracy                           0.96       182
#    macro avg       0.96      0.96      0.96       182
# weighted avg       0.96      0.96      0.96       182
#
#
# Confusion Matrix:

# %%
device, model, criterion, optimizer = declare_model(model_llm='gpt2', kernel_size=KERNEL_SIZE, learning_rate=LEARNING_RATE)
training(train_loader, val_loader, model, criterion, optimizer, device, epochs=EPOCH, patience=PATIENCE, min_delta=MIN_DELTA)
evaluate(test_loader, model, criterion, optimizer, device)
# Out:
# Training CNN with Embedding gpt2
#
# CNN Architecture:
# CNNModel(
#   (embedding): Embedding(2521, 1024, padding_idx=0)
#   (layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#   (conv1): Conv1d(1024, 256, kernel_size=(3,), stride=(1,))
#   (bn1): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv2): Conv1d(256, 128, kernel_size=(3,), stride=(1,))
#   (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv3): Conv1d(128, 64, kernel_size=(3,), stride=(1,))
#   (bn3): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (maxpool): MaxPool1d(kernel_size=3, stride=3, padding=0, dilation=1, ceil_mode=False)
#   (global_maxpool): AdaptiveMaxPool1d(output_size=1)
#   (dropout): Dropout(p=0.2, inplace=False)
#   (f
# Epoch 54/100, Train Loss: 0.029, Val Loss: 0.263, Train Accuracy: 0.999, Val Accuracy: 0.870
# Epoch 55/100, Train Loss: 0.026, Val Loss: 0.022, Train Accuracy: 0.999, Val Accuracy: 1.000
# Epoch 56/100, Train Loss: 0.027, Val Loss: 0.032, Train Accuracy: 0.997, Val Accuracy: 1.000
# Epoch 57/100, Train Loss: 0.021, Val Loss: 0.038, Train Accuracy: 0.998, Val Accuracy: 0.978
# Epoch 58/100, Train Loss: 0.021, Val Loss: 0.021, Train Accuracy: 0.999, Val Accuracy: 1.000
# Epoch 59/100, Train Loss: 0.015, Val Loss: 0.083, Train Accuracy: 1.000, Val Accuracy: 0.978
# Epoch 60/100, Train Loss: 0.015, Val Loss: 0.056, Train Accuracy: 1.000, Val Accuracy: 0.978
# Epoch 61/100, Train Loss: 0.017, Val Loss: 0.050, Train Accuracy: 1.000, Val Accuracy: 0.978
# Epoch 62/100, Train Loss: 0.018, Val Loss: 0.159, Train Accuracy: 0.999, Val Accuracy: 0.935
# Epoch 63/100, Train Loss: 0.017, Val Loss: 0.028, Train Accuracy: 0.999, Val Accuracy: 1.000
# Epoch 64/100, Train Loss: 0.014, Val Loss: 0.024, Train Accuracy: 1.000, Val Accuracy: 1.000
# Epoch 65/100, Train Loss: 0.013, Val Loss: 0.019, Train Accuracy: 1.000, Val Accuracy: 1.000
# Epoch 66/100, Train Loss: 0.015, Val Loss: 0.075, Train Accuracy: 0.998, Val Accuracy: 0.978
# Epoch 67/100, Train Loss: 0.011, Val Loss: 0.037, Train Accuracy: 1.000, Val Accuracy: 0.978
# Epoch 68/100, Train Loss: 0.013, Val Loss: 0.036, Train Accuracy: 1.000, Val Accuracy: 0.978
# Epoch 69/100, Train Loss: 0.011, Val Loss: 0.044, Train Accuracy: 1.000, Val Accuracy: 0.978
# Epoch 70/100, Train Loss: 0.025, Val Loss: 0.170, Train Accuracy: 0.995, Val Accuracy: 0.935
# Epoch 71/100, Train Loss: 0.027, Val Loss: 0.060, Train Accuracy: 0.997, Val Accuracy: 0.978
# Epoch 72/100, Train Loss: 0.017, Val Loss: 0.093, Train Accuracy: 0.999, Val Accuracy: 0.978
# Epoch 73/100, Train Loss: 0.014, Val Loss: 0.056, Train Accuracy: 1.000, Val Accuracy: 0.978
# Epoch 74/100, Train Loss: 0.014, Val Loss: 0.050, Train Accuracy: 1.000, Val Accuracy: 0.978
# Epoch 75/100, Train Loss: 0.013, Val Loss: 0.029, Train Accuracy: 0.999, Val Accuracy: 0.978
# Early stopping
#
# Total Training Time: 5.92 seconds
# Test Loss: 0.111, Test Accuracy: 0.950
#
# Matthews Correlation Coefficient: 0.901
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.95      0.95        91
#          1.0       0.95      0.96      0.95        91
#
#     accuracy                           0.95       182
#    macro avg       0.95      0.95      0.95       182
# weighted avg       0.95      0.95      0.95       182
#
#
# Confusion Matrix:

# %%
device, model, criterion, optimizer = declare_model(model_llm='llama2', kernel_size=KERNEL_SIZE, learning_rate=LEARNING_RATE)
training(train_loader, val_loader, model, criterion, optimizer, device, epochs=EPOCH, patience=PATIENCE, min_delta=MIN_DELTA)
evaluate(test_loader, model, criterion, optimizer, device)
# Out:
# Training CNN with Embedding llama2
#
# CNN Architecture:
# CNNModel(
#   (embedding): Embedding(2521, 4096, padding_idx=0)
#   (layer_norm): LayerNorm((4096,), eps=1e-05, elementwise_affine=True)
#   (conv1): Conv1d(4096, 256, kernel_size=(3,), stride=(1,))
#   (bn1): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv2): Conv1d(256, 128, kernel_size=(3,), stride=(1,))
#   (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv3): Conv1d(128, 64, kernel_size=(3,), stride=(1,))
#   (bn3): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (maxpool): MaxPool1d(kernel_size=3, stride=3, padding=0, dilation=1, ceil_mode=False)
#   (global_maxpool): AdaptiveMaxPool1d(output_size=1)
#   (dropout): Dropout(p=0.2, inplace=False)
#   (fc1): Linear(in_features=64, out_features=32, bias=True)
#   (fc2): Linear(in_features=32, out_features=1, bias=True)
#   (relu): ReLU()
# )
#
# Epoch 1/100, Train Loss: 0.615, Val Loss: 0.612, Train Accuracy: 0.591, Val Accuracy: 0.522
# Epoch 2/100, Train Loss: 0.530, Val Loss: 0.483, Train Accuracy: 0.812, Val Accuracy: 0.891
# Epoch 3/100, Train Loss: 0.475, Val Loss: 0.419, Train Accuracy: 0.871, Val Accuracy: 0.913
# Epoch 4/100, Train Loss: 0.426, Val Loss: 0.370, Train Accuracy: 0.887, Val Accuracy: 0.957
# Epoch 5/100, Train Loss: 0.377, Val Loss: 0.331, Train Accuracy: 0.925, Val Accuracy: 0.957
# Epoch 6/100, Train Loss: 0.324, Val Loss: 0.287, Train Accuracy: 0.947, Val Accuracy: 0.957
# Epoch 7/100, Train Loss: 0.282, Val Loss: 0.276, Train Accuracy: 0.958, Val Accuracy: 0.957
# Epoch 8/100, Train Loss: 0.237, Val Loss: 0.244, Train Accuracy: 0.973, Val Accuracy: 0.978
# Epoch 9/100, Train Loss: 0.200, Val Loss: 0.206, Train Accuracy: 0.971, Val Accuracy: 0.978
# Epoch 10/100, Train Loss: 0.176, Val Loss: 0.221, Train Accuracy: 0.991, Val Accuracy: 0.978
# Epoch 11/100, Train Loss: 0.150, Val Loss: 0.164, Train Accuracy: 0.994, Val Accuracy: 1.000
# Epoch 12/100, Train Loss: 0.127, Val Loss: 0.147, Train Accuracy: 0.992, Val Accuracy: 1.000
# Epoch 13/100, Train Loss: 0.107, Val Loss: 0.141, Train Accuracy: 0.997, Val Accuracy: 0.978
# Epoch 14/100, Train Loss: 0.092, Val Loss: 0.133, Train Accuracy: 1.000, Val Accuracy: 1.000
# Epoch 15/100, Train Loss: 0.085, Val Loss: 0.120, Train Accuracy: 1.000, Val Accuracy: 0.978
# Epoch 16/100, Train Loss: 0.072, Val Loss: 0.194, Train Accuracy: 1.000, Val Accuracy: 0.935
# Epoch 17/100, Train Loss: 0.063, Val Loss: 0.101, Train Accuracy: 0.995, Val Accuracy: 1.000
# Epoch 18/100, Train Loss: 0.056, Val Loss: 0.101, Train Accuracy: 1.000, Val Accuracy: 1.000
# Epoch 19/100, Train Loss: 0.055, Val Loss: 0.096, Train Accuracy: 1.000, Val Accuracy: 1.000
# Epoch 20/100, Train Loss: 0.049, Val Loss: 0.085, Train Accuracy: 1.000, Val Accuracy: 1.000
# Epoch 21/100, Train Loss: 0.045, Val Loss: 0.124, Train Accuracy: 1.000, Val Accuracy: 0.957
# Epoch 22/100, Train Loss: 0.040, Val Loss: 0.068, Train Accuracy: 1.000, Val Accuracy: 1.000
# Epoch