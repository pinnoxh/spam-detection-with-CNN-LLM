# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import time

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import matthews_corrcoef
from transformers import get_linear_schedule_with_warmup

import torch
import torch.nn as nn
import torch.optim as optim
# Out:
# 2024-12-05 08:36:29.899492: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-12-05 08:36:29.924332: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-12-05 08:36:29.933008: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-05 08:36:29.951244: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-12-05 08:36:31.662964: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
df = pd.read_excel('/home/basilmusyaffa19/Skripsi Basil/Dataset/FIX/clean_SMS_22112024.xlsx', engine='openpyxl')
df
# Out:
#                                                    teks  label
# 0     promo beli paket flash mulai aplikasi my telko...      1
# 1     gb hari rp ribu spesial buat kamu pilih aktif ...      1
# 2     plg hormat sisa kuota flash download aplikasi ...      1
# 3     mohon hormat sisa kuota flash download aplikas...      1
# 4     hari rp ribu khusus buat kamu pilih aktif seka...      1
# ...                                                 ...    ...
# 1138             yooo sama sama aku umum kelompok kelas      0
# 1139         pernah tulis cadar belum pikir warna jeans      0
# 1140                                       bu mau kirim      0
# 1141                  berangkat pagi mau tunai transfer      0
# 1142                         berapa nomor bri atas nama      0
#
# [1143 rows x 2 columns]

# %%
print("Jumlah data sebelum:", len(df))

# Menghapus data kosong
df = df.replace('', np.nan).dropna()
# Hapus NaN
df = df.dropna(subset=['teks'])
# Menghapus nilai float
df = df[~df['teks'].apply(lambda x: isinstance(x, float))]
# Menghapus semua baris yang duplikat
df = df.drop_duplicates(subset=['teks'], keep='first')

print("Jumlah data setelah:", len(df))
# Out:
# Jumlah data sebelum: 1143
# Jumlah data setelah: 1138

# %%
label = df['label'].value_counts()
print(label)
# Out:
# label
# 1    571
# 0    567
# Name: count, dtype: int64

# %%
import pickle

def padding_texts(df):
    with open('/home/basilmusyaffa19/Skripsi Basil/Embedding Matrix/Dataset Indo/indo_keras_tokenizer.pickle', 'rb') as handle:
        keras_tokenizer = pickle.load(handle)

    sequences = keras_tokenizer.texts_to_sequences(df['teks'])
    max_length = max(len(seq) for seq in sequences)
    padded_sequences = pad_sequences(sequences, maxlen=max_length)
    vocab_size = len(keras_tokenizer.word_index) + 1
    
    return padded_sequences, vocab_size

# %%
def split_data(padded_sequences, labels, test_size, val_size, random_state=42):
    X_train, X_temp, y_train, y_temp = train_test_split(
        padded_sequences,
        labels,
        test_size=test_size,
        stratify=labels,
        random_state=random_state,
    )

    X_test, X_val, y_test, y_val = train_test_split(
        X_temp,
        y_temp,
        test_size=val_size,
        stratify=y_temp,
        random_state=random_state,
    )
    
    print(f'X_train Shape: {X_train.shape}')
    print(f'X_val Shape: {X_val.shape}')
    print(f'X_test Shape: {X_test.shape}')
    print('')
    
    print(f'y_train Class: {y_train.nunique()}')
    print(f'y_val Class: {y_val.nunique()}')
    print(f'y_test Class: {y_test.nunique()}')
    print('')
    
    return X_train, X_val, X_test, y_train, y_val, y_test

# %%
def create_data_loaders(X_train, X_val, X_test, y_train, y_val, y_test, batch_size):
    y_train = torch.tensor(y_train.values, dtype=torch.float32)
    y_val = torch.tensor(y_val.values, dtype=torch.float32)
    y_test = torch.tensor(y_test.values, dtype=torch.float32)

    X_train = torch.tensor(X_train, dtype=torch.int64)
    X_val = torch.tensor(X_val, dtype=torch.int64)
    X_test = torch.tensor(X_test, dtype=torch.int64)

    train_dataset = TensorDataset(X_train, y_train)
    val_dataset = TensorDataset(X_val, y_val)
    test_dataset = TensorDataset(X_test, y_test)

    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
    
    return train_loader, val_loader, test_loader

# %%
def prepare_data_loader(df, test_size, val_size, batch_size, random_state=42):
    padded_sequences, vocab_size = padding_texts(df)
    X_train, X_val, X_test, y_train, y_val, y_test = split_data(padded_sequences, df['label'], test_size, val_size, random_state)
    train_loader, val_loader, test_loader = create_data_loaders(X_train, X_val, X_test, y_train, y_val, y_test, batch_size=batch_size)
    
    return train_loader, val_loader, test_loader, vocab_size

# %%
class CNNModel(nn.Module):
    def __init__(self, embedding_matrix, embedding_dim, kernel_size, output_dim=1):
        super(CNNModel, self).__init__()
        
        # Embedding layer dengan Layer Normalization
        self.embedding = nn.Embedding.from_pretrained(embedding_matrix, freeze=True, padding_idx=0)
        self.layer_norm = nn.LayerNorm(embedding_dim)
        
        # Conv1 block dengan Batch Normalization
        self.conv1 = nn.Conv1d(in_channels=embedding_dim, out_channels=256, kernel_size=kernel_size)
        self.bn1 = nn.BatchNorm1d(256)
        
        # Conv2 block dengan Batch Normalization
        self.conv2 = nn.Conv1d(in_channels=256, out_channels=128, kernel_size=kernel_size)
        self.bn2 = nn.BatchNorm1d(128)
        
        # Conv3 block dengan Batch Normalization
        self.conv3 = nn.Conv1d(in_channels=128, out_channels=64, kernel_size=kernel_size)
        self.bn3 = nn.BatchNorm1d(64)
        
        # Conv4 block dengan Batch Normalization (Tambahan)
        self.conv4 = nn.Conv1d(in_channels=64, out_channels=32, kernel_size=kernel_size)
        self.bn4 = nn.BatchNorm1d(32)
        
        self.maxpool = nn.MaxPool1d(kernel_size=kernel_size)
        self.global_maxpool = nn.AdaptiveMaxPool1d(1)
        self.dropout = nn.Dropout(p=0.2)
        
        # Fully connected layers
        self.fc1 = nn.Linear(32,16)
        self.fc2 = nn.Linear(16, output_dim)
        self.relu = nn.ReLU()
        
    def forward(self, x):
        # Embedding layer dengan Layer Normalization
        x = self.embedding(x)
        x = self.layer_norm(x)
        x = x.permute(0, 2, 1)
        
        # Conv1 block
        x = self.conv1(x)
        x = self.bn1(x)
        x = self.relu(x)
        x = self.dropout(x)
        
        # Conv2 block
        x = self.conv2(x)
        x = self.bn2(x)
        x = self.relu(x)
        x = self.maxpool(x)
        x = self.dropout(x)
        
        # Conv3 block
        x = self.conv3(x)
        x = self.bn3(x)
        x = self.relu(x)
        x = self.dropout(x)
        
        # Conv4 block
        x = self.conv4(x)
        x = self.bn4(x)
        x = self.relu(x)
        
        # Global pooling
        x = self.global_maxpool(x).squeeze(-1)
        x = self.dropout(x)
        
        # Fully connected layers
        x = self.relu(self.fc1(x))
        x = self.dropout(x)
        x = torch.sigmoid(self.fc2(x))
        
        return x.squeeze(-1)

# %%
class EarlyStopping:
    def __init__(self, patience, min_delta):
        self.patience = patience
        self.min_delta = min_delta
        self.counter = 0
        self.best_loss = None
        self.early_stop = False

    def __call__(self, val_loss):
        if self.best_loss is None:
            self.best_loss = val_loss
        elif val_loss < self.best_loss - self.min_delta: # Jika ada improvement
            self.best_loss = val_loss
            self.counter = 0
        else:  # Jika tidak ada improvement
            self.counter += 1
            if self.counter >= self.patience:
                self.early_stop = True

# %%
def prepare_embedding_matrix(model):
    paths = {
        'gpt2': '/home/basilmusyaffa19/Skripsi Basil/Embedding Matrix/Dataset Indo/Hasil Embedding/21 Nov/embedding_matrix_gpt2_1024D_21112024.npy',
        'llama2': '/home/basilmusyaffa19/Skripsi Basil/Embedding Matrix/Dataset Indo/Hasil Embedding/21 Nov/embedding_matrix_llama2_4096D_21112024.npy',
        'XLM-R': '/home/basilmusyaffa19/Skripsi Basil/Embedding Matrix/Dataset Indo/Hasil Embedding/21 Nov/embedding_matrix_XLMroBERTaLarge_1024D_21112024.npy',
        'mT5': '/home/basilmusyaffa19/Skripsi Basil/Embedding Matrix/Dataset Indo/Hasil Embedding/21 Nov/embedding_matrix_mt5Large_1024D_21112024.npy',
        'gloveWiki': '/home/basilmusyaffa19/Skripsi Basil/Embedding Matrix/Dataset Indo/Hasil Embedding/21 Nov/embedding_matrix_gloveWiki_50D_21112024.npy',
        'indoBERT': '/home/basilmusyaffa19/Skripsi Basil/Embedding Matrix/Dataset Indo/Hasil Embedding/21 Nov/embedding_matrix_indoBERTLarge_1024D_21112024.npy',
    }
    
    path = paths.get(model)
    
    if path:
        embedding_matrix = np.load(path)
        embedding_dim = embedding_matrix.shape[1]
        embedding_matrix = torch.tensor(embedding_matrix, dtype=torch.float32)
        return embedding_matrix, embedding_dim
    else:
        raise ValueError(f"Model '{model}' is not recognized")

def declare_model(model_llm, kernel_size, learning_rate):
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    print(f"Training CNN with Embedding {model_llm} \n")
    embedding_matrix, embedding_dim = prepare_embedding_matrix(model=model_llm)
    model = CNNModel(embedding_matrix, embedding_dim, kernel_size)
    model.to(device)
    criterion = nn.BCELoss()
    optimizer = optim.Adam(model.parameters(), 
                           lr=learning_rate,
                           weight_decay=1e-4)
    
    print('CNN Architecture:')
    print(model)
    print('')
    
    return device, model, criterion, optimizer

# %%
def binary_accuracy(y_pred, y_true):
    y_pred_tags = (y_pred > 0.5).long()
    correct_results_sum = (y_pred_tags == y_true).sum().float()
    acc = correct_results_sum / y_true.shape[0]
    return acc

def training(train_loader, val_loader, model, criterion, optimizer, device, epochs, patience, min_delta):
    torch.cuda.empty_cache()
    
    total_start_time = time.time()
    early_stopping = EarlyStopping(patience=patience, min_delta=min_delta)
    
    num_training_steps = epochs * len(train_loader)
    
    scheduler = get_linear_schedule_with_warmup(
        optimizer,
        num_warmup_steps=0,
        num_training_steps=num_training_steps
    )
    
    train_losses = []
    val_losses = []
    
    for epoch in range(epochs):
        model.train()
        train_loss_final = 0.0
        train_accuracy_final = 0.0
        for X_train, y_train in train_loader:
            X_train, y_train = X_train.to(device), y_train.to(device)
            optimizer.zero_grad()
            
            y_train_pred = model(X_train)
            train_loss = criterion(y_train_pred, y_train.float())
            train_accuracy = binary_accuracy(y_train_pred, y_train)
            
            train_loss.backward()
            optimizer.step()
            scheduler.step()
            
            train_loss_final += train_loss.item()
            train_accuracy_final += train_accuracy.item()
        avg_train_loss = train_loss_final / len(train_loader)
        avg_train_accuracy = train_accuracy_final / len(train_loader)
        train_losses.append(avg_train_loss)
        
        model.eval()
        val_loss_final = 0.0
        val_accuracy_final = 0.0
        with torch.no_grad():
            for X_val, y_val in val_loader:
                X_val, y_val = X_val.to(device), y_val.to(device)
                
                y_val_pred = model(X_val)
                val_loss = criterion(y_val_pred, y_val.float())
                val_accuracy = binary_accuracy(y_val_pred, y_val)
                
                val_loss_final += val_loss.item()
                val_accuracy_final += val_accuracy.item()
            avg_val_loss = val_loss_final / len(val_loader)
            avg_val_accuracy = val_accuracy_final / len(val_loader)
            val_losses.append(avg_val_loss)

        print(f'Epoch {epoch+1}/{epochs}, Train Loss: {avg_train_loss:.3f}, Val Loss: {avg_val_loss:.3f}, Train Accuracy: {avg_train_accuracy:.3f}, Val Accuracy: {avg_val_accuracy:.3f}')
    
        early_stopping(avg_val_loss)
    
        if early_stopping.early_stop:
            print("Early stopping")
            break
            
    total_end_time = time.time()
    total_time = total_end_time - total_start_time
    print(f'\nTotal Training Time: {total_time:.2f} seconds')
    
    # Plot learning curves
    plt.figure(figsize=(10, 5))
    plt.plot(train_losses, label='Train Loss')
    plt.plot(val_losses, label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Learning Curve')
    plt.legend()
    plt.show()

# %%
def evaluate(test_loader, model, criterion, optimizer, device):
    model.eval()
    test_loss_final = 0.0
    test_accuracy_final = 0.0
    y_pred_list = []
    y_test_list = []
    for X_test, y_test in test_loader:
        X_test, y_test = X_test.to(device), y_test.to(device)
        
        y_test_pred = model(X_test)
        test_loss = criterion(y_test_pred, y_test.float())
        test_accuracy = binary_accuracy(y_test_pred, y_test)
        
        test_loss_final += test_loss.item()
        test_accuracy_final += test_accuracy.item()
        
        y_pred_tags = (y_test_pred > 0.5).long()
        y_pred_list.append(y_pred_tags.cpu().numpy())
        y_test_list.append(y_test.cpu().numpy())
        
    avg_test_loss = test_loss_final / len(test_loader)
    avg_test_accuracy = test_accuracy_final / len(test_loader)
    
    print(f'Test Loss: {avg_test_loss:.3f}, Test Accuracy: {avg_test_accuracy:.3f}')
    print('')
    
    y_pred_list = np.concatenate([a.squeeze() for a in y_pred_list]).tolist()
    y_test_list = np.concatenate([a.squeeze() for a in y_test_list]).tolist()
    
    mcc = matthews_corrcoef(y_test_list, y_pred_list)
    print(f'Matthews Correlation Coefficient: {mcc:.3f}')
    print('')
    
    cm = confusion_matrix(y_test_list, y_pred_list)
    print('Classification Report:')
    print(classification_report(y_test_list, y_pred_list))
    print('')
    
    print('Confusion Matrix:')
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Predicted 0', 'Predicted 1'], yticklabels=['Actual 0', 'Actual 1'])
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.title('Confusion Matrix')
    plt.show()

# %%
LEARNING_RATE = 1e-4
EPOCH = 100
BATCH_SIZE = 64
KERNEL_SIZE = 3
PATIENCE = 10
MIN_DELTA= 1e-3

# %%
train_loader, val_loader, test_loader, vocab_size = prepare_data_loader(df, test_size=0.2, val_size=0.2, batch_size=BATCH_SIZE)
# Out:
# X_train Shape: (910, 44)
# X_val Shape: (46, 44)
# X_test Shape: (182, 44)
#
# y_train Class: 2
# y_val Class: 2
# y_test Class: 2

# %%
device, model, criterion, optimizer = declare_model(model_llm='gloveWiki', kernel_size=KERNEL_SIZE, learning_rate=LEARNING_RATE)
training(train_loader, val_loader, model, criterion, optimizer, device, epochs=EPOCH, patience=PATIENCE, min_delta=MIN_DELTA)
evaluate(test_loader, model, criterion, optimizer, device)
# Out:
# Training CNN with Embedding gloveWiki
#
# CNN Architecture:
# CNNModel(
#   (embedding): Embedding(2521, 50, padding_idx=0)
#   (layer_norm): LayerNorm((50,), eps=1e-05, elementwise_affine=True)
#   (conv1): Conv1d(50, 256, kernel_size=(3,), stride=(1,))
#   (bn1): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv2): Conv1d(256, 128, kernel_size=(3,), stride=(1,))
#   (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv3): Conv1d(128, 64, kernel_size=(3,), stride=(1,))
#   (bn3): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv4): Conv1d(64, 32, kernel_size=(3,), stride=(1,))
#   (bn4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (maxpool): MaxPool1d(kernel_size=3, stride=3, padding=0, dilation=1, ceil_mode=False)
#   (global_maxpool): AdaptiveMaxPool1d(output_size=1)
#   (dropout): Dropout(p=0.2, inplace=False)
#   (fc1): Linear(in_features=32, out_features=16, bias=True)
#   (fc2): Linear(in_features=16, out_features=1, bias=True)
#   (relu): ReLU()
# )
#
# Epoch 1/100, Train Loss: 0.597, Val Loss: 0.641, Train Accuracy: 0.636, Val Accuracy: 0.913
# Epoch 2/100, Train Loss: 0.553, Val Loss: 0.522, Train Accuracy: 0.759, Val Accuracy: 0.957
# Epoch 3/100, Train Loss: 0.536, Val Loss: 0.470, Train Accuracy: 0.790, Val Accuracy: 0.957
# Epoch 4/100, Train Loss: 0.525, Val Loss: 0.448, Train Accuracy: 0.815, Val Accuracy: 0.957
# Epoch 5/100, Train Loss: 0.505, Val Loss: 0.448, Train Accuracy: 0.856, Val Accuracy: 0.957
# Epoch 6/100, Train Loss: 0.510, Val Loss: 0.427, Train Accuracy: 0.852, Val Accuracy: 0.957
# Epoch 7/100, Train Loss: 0.485, Val Loss: 0.433, Train Accuracy: 0.892, Val Accuracy: 0.957
# Epoch 8/100, Train Loss: 0.470, Val Loss: 0.422, Train Accuracy: 0.881, Val Accuracy: 0.957
# Epoch 9/100, Train Loss: 0.461, Val Loss: 0.410, Train Accuracy: 0.895, Val Accuracy: 0.957
# Epoch 10/100, Train Loss: 0.455, Val Loss: 0.404, Train Accuracy: 0.884, Val Accuracy: 0.978
# Epoch 11/100, Train Loss: 0.445, Val Loss: 0.400, Train Accuracy: 0.897, Val Accuracy: 0.978
# Epoch 12/100, Train Loss: 0.440, Val Loss: 0.400, Train Accuracy: 0.900, Val Accuracy: 0.978
# Epoch 13/100, Train Loss: 0.433, Val Loss: 0.390, Train Accuracy: 0.897, Val Accuracy: 0.978
# Epoch 14/100, Train Loss: 0.427, Val Loss: 0.389, Train Accuracy: 0.906, Val Accuracy: 0.978
# Epoch 15/100, Train Loss: 0.418, Val Loss: 0.383, Train Accuracy: 0.928, Val Accuracy: 0.978
# Epoch 16/100, Train Loss: 0.417, Val Loss: 0.368, Train Accuracy: 0.907, Val Accuracy: 1.000
# Epoch 17/100, Train Loss: 0.402, Val Loss: 0.381, Train Accuracy: 0.918, Val Accuracy: 0.957
# Epoch 18/100, Train Loss: 0.390, Val Loss: 0.375, Train Accuracy: 0.930, Val Accuracy: 0.978
# Epoch 19/100, Train Loss: 0.381, Val Loss: 0.366, Train Accuracy: 0.935, Val Accuracy: 1.000
# Epoch 20/100, Train Loss: 0.373, Val Loss: 0.361, Train Accuracy: 0.930, Val Accuracy: 1.000
# Epoch 21/100, Train Loss: 0.375, Val Loss: 0.357, Train Accuracy: 0.930, Val Accuracy: 0.978
# Epoch 22/100, Train Loss: 0.350, Val Loss: 0.353, Train Accuracy: 0.944, Val Accuracy: 0.978
# Epoch 23/100, Train Loss: 0.351, Val Loss: 0.343, Train Accuracy: 0.940, Val Accuracy: 0.978
# Epoch 24/100, Train Loss: 0.358, Val Loss: 0.338, Train Accuracy: 0.929, Val Accuracy: 0.978
# Epoch 25/100, Train Loss: 0.334, Val Loss: 0.344, Train Accuracy: 0.950, Val Accuracy: 0.935
# Epoch 26/100, Train Loss: 0.339, Val Loss: 0.339, Train Accuracy: 0.941, Val Accuracy: 0.935
# Epoch 27/100, Train Loss: 0.329, Val Loss: 0.330, Train Accuracy: 0.938, Val Accuracy: 0.935
# Epoch 28/100, Train Loss: 0.319, Val Loss: 0.319, Train Accuracy: 0.944, Val Accuracy: 0.957
# Epoch 29/100, Train Loss: 0.310, Val Loss: 0.322, Train Accuracy: 0.942, Val Accuracy: 0.935
# Epoch 30/100, Train Loss: 0.303, Val Loss: 0.318, Train Accuracy: 0.946, Val Accuracy: 0.935
# Epoch 31/100, Train Loss: 0.288, Val Loss: 0.323, Train Accuracy: 0.961, Val Accuracy: 0.935
# Epoch 32/100, Train Loss: 0.295, Val Loss: 0.296, Train Accuracy: 0.948, Val Accuracy: 0.957
# Epoch 33/100, Train Loss: 0.268, Val Loss: 0.297, Train Accuracy: 0.974, Val Accuracy: 0.935
# Epoch 34/100, Train Loss: 0.264, Val Loss: 0.288, Train Accuracy: 0.966, Val Accuracy: 0.957
# Epoch 35/100, Train Loss: 0.258, Val Loss: 0.286, Train Accuracy: 0.969, Val Accuracy: 0.957
# Epoch 36/100, Train Loss: 0.247, Val Loss: 0.279, Train Accuracy: 0.970, Val Accuracy: 0.957
# Epoch 37/100, Train Loss: 0.237, Val Loss: 0.275, Train Accuracy: 0.973, Val Accuracy: 0.935
# Epoch 38/100, Train Loss: 0.233, Val Loss: 0.264, Train Accuracy: 0.977, Val Accuracy: 0.935
# Epoch 39/100, Train Loss: 0.227, Val Loss: 0.268, Train Accuracy: 0.975, Val Accuracy: 0.935
# Epoch 40/100, Train Loss: 0.225, Val Loss: 0.249, Train Accuracy: 0.972, Val Accuracy: 0.957
# Epoch 41/100, Train Loss: 0.221, Val Loss: 0.251, Train Accuracy: 0.967, Val Accuracy: 0.935
# Epoch 42/100, Train Loss: 0.210, Val Loss: 0.240, Train Accuracy: 0.969, Val Accuracy: 0.957
# Epoch 43/100, Train Loss: 0.189, Val Loss: 0.254, Train Accuracy: 0.982, Val Accuracy: 0.935
# Epoch 44/100, Train Loss: 0.195, Val Loss: 0.221, Train Accuracy: 0.974, Val Accuracy: 0.978
# Epoch 45/100, Train Loss: 0.196, Val Loss: 0.224, Train Accuracy: 0.978, Val Accuracy: 0.957
# Epoch 46/100, Train Loss: 0.185, Val Loss: 0.233, Train Accuracy: 0.980, Val Accuracy: 0.957
# Epoch 47/100, Train Loss: 0.182, Val Loss: 0.205, Train Accuracy: 0.983, Val Accuracy: 0.978
# Epoch 48/100, Train Loss: 0.167, Val Loss: 0.245, Train Accuracy: 0.979, Val Accuracy: 0.913
# Epoch 49/100, Train Loss: 0.161, Val Loss: 0.192, Train Accuracy: 0.988, Val Accuracy: 1.000
# Epoch 50/100, Train Loss: 0.168, Val Loss: 0.216, Train Accuracy: 0.981, Val Accuracy: 0.913
# Epoch 51/100, Train Loss: 0.161, Val Loss: 0.214, Train Accuracy: 0.980, Val Accuracy: 0.913
# Epoch 52/100, Train Loss: 0.154, Val Loss: 0.191, Train Accuracy: 0.979, Val Accuracy: 1.000
# Epoch 53/100, Train Loss: 0.154, Val Loss: 0.199, Train Accuracy: 0.981, Val Accuracy: 0.935
# Epoch 54/100, Train Loss: 0.147, Val Loss: 0.194, Train Accuracy: 0.984, Val Accuracy: 0.957
# Epoch 55/100, Train Loss: 0.140, Val Loss: 0.199, Train Accuracy: 0.993, Val Accuracy: 0.935
# Epoch 56/100, Train Loss: 0.135, Val Loss: 0.198, Train Accuracy: 0.992, Val Accuracy: 0.935
# Epoch 57/100, Train Loss: 0.133, Val Loss: 0.196, Train Accuracy: 0.982, Val Accuracy: 0.935
# Epoch 58/100, Train Loss: 0.126, Val Loss: 0.183, Train Accuracy: 0.988, Val Accuracy: 0.935
# Epoch 59/100, Train Loss: 0.141, Val Loss: 0.175, Train Accuracy: 0.985, Val Accuracy: 0.957
# Epoch 60/100, Train Loss: 0.127, Val Loss: 0.179, Train Accuracy: 0.992, Val Accuracy: 0.978
# Epoch 61/100, Train Loss: 0.123, Val Loss: 0.155, Train Accuracy: 0.992, Val Accuracy: 1.000
# Epoch 62/100, Train Loss: 0.120, Val Loss: 0.176, Train Accuracy: 0.989, Val Accuracy: 0.957
# Epoch 63/100, Train Loss: 0.125, Val Loss: 0.200, Train Accuracy: 0.990, Val Accuracy: 0.935
# Epoch 64/100, Train Loss: 0.118, Val Loss: 0.183, Train Accuracy: 0.986, Val Accuracy: 0.935
# Epoch 65/100, Train Loss: 0.115, Val Loss: 0.171, Train Accuracy: 0.993, Val Accuracy: 0.935
# Epoch 66/100, Train Loss: 0.113, Val Loss: 0.163, Train Accuracy: 0.993, Val Accuracy: 0.957
# Epoch 67/100, Train Loss: 0.110, Val Loss: 0.182, Train Accuracy: 0.995, Val Accuracy: 0.935
# Epoch 68/100, Train Loss: 0.109, Val Loss: 0.161, Train Accuracy: 0.997, Val Accuracy: 0.957
# Epoch 69/100, Train Loss: 0.107, Val Loss: 0.143, Train Accuracy: 0.994, Val Accuracy: 1.000
# Epoch 70/100, Train Loss: 0.110, Val Loss: 0.173, Train Accuracy: 0.989, Val Accuracy: 0.935
# Epoch 71/100, Train Loss: 0.136, Val Loss: 0.160, Train Accuracy: 0.979, Val Accuracy: 0.935
# Epoch 72/100, Train Loss: 0.112, Val Loss: 0.191, Train Accuracy: 0.992, Val Accuracy: 0.913
# Epoch 73/100, Train Loss: 0.103, Val Loss: 0.149, Train Accuracy: 0.994, Val Accuracy: 0.957
# Epoch 74/100, Train Loss: 0.100, Val Loss: 0.154, Train Accuracy: 0.996, Val Accuracy: 0.957
# Epoch 75/100, Train Loss: 0.096, Val Loss: 0.163, Train Accuracy: 0.994, Val Accuracy: 0.957
# Epoch 76/100, Train Loss: 0.102, Val Loss: 0.152, Train Accuracy: 0.995, Val Accuracy: 0.957
# Epoch 77/100, Train Loss: 0.095, Val Loss: 0.154, Train Accuracy: 0.995, Val Accuracy: 0.957
# Epoch 78/100, Train Loss: 0.099, Val Loss: 0.149, Train Accuracy: 0.992, Val Accuracy: 0.978
# Epoch 79/100, Train Loss: 0.094, Val Loss: 0.148, Train Accuracy: 0.995, Val Accuracy: 0.978
# Early stopping
#
# Total Training Time: 8.25 seconds
# Test Loss: 0.222, Test Accuracy: 0.924
#
# Matthews Correlation Coefficient: 0.847
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.91      0.95      0.92        91
#          1.0       0.94      0.90      0.92        91
#
#     accuracy                           0.92       182
#    macro avg       0.92      0.92      0.92       182
# weighted avg       0.92      0.92      0.92       182
#
#
# Confusion Matrix:

# %%
device, model, criterion, optimizer = declare_model(model_llm='indoBERT', kernel_size=KERNEL_SIZE, learning_rate=LEARNING_RATE)
training(train_loader, val_loader, model, criterion, optimizer, device, epochs=EPOCH, patience=PATIENCE, min_delta=MIN_DELTA)
evaluate(test_loader, model, criterion, optimizer, device)
# Out:
# Training CNN with Embedding indoBERT
#
# CNN Architecture:
# CNNModel(
#   (embedding): Embedding(2521, 1024, padding_idx=0)
#   (layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#   (conv1): Conv1d(1024, 256, kernel_size=(3,), stride=(1,))
#   (bn1): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv2): Conv1d(256, 128, kernel_size=(3,), stride=(1,))
#   (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv3): Conv1d(128, 64, kernel_size=(3,), stride=(1,))
#   (bn3): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv4): Conv1d(64, 32, kernel_size=(3,), stride=(1,))
#   (bn4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (maxpool): MaxPool1d(kernel_size=3, stride=3, padding=0, dilation=1, ceil_mode=False)
#   (global_maxpool): AdaptiveMaxPool1d(output_size=1)
#   (dropout): Dropout(p=0.2, inplace=False)
#   (fc1): Linear(in_features=32, out_features=16, bias=True)
#   (fc2): Linear(in_features=16, out_features=1, bias=True)
#   (relu): ReLU()
# )
#
# Epoch 1/100, Train Loss: 0.651, Val Loss: 0.658, Train Accuracy: 0.650, Val Accuracy: 0.522
# Epoch 2/100, Train Loss: 0.604, Val Loss: 0.580, Train Accuracy: 0.717, Val Accuracy: 0.935
# Epoch 3/100, Train Loss: 0.586, Val Loss: 0.535, Train Accuracy: 0.760, Val Accuracy: 0.935
# Epoch 4/100, Train Loss: 0.562, Val Loss: 0.527, Train Accuracy: 0.773, Val Accuracy: 0.935
# Epoch 5/100, Train Loss: 0.546, Val Loss: 0.518, Train Accuracy: 0.798, Val Accuracy: 0.935
# Epoch 6/100, Train Loss: 0.534, Val Loss: 0.510, Train Accuracy: 0.791, Val Accuracy: 0.935
# Epoch 7/100, Train Loss: 0.539, Val Loss: 0.503, Train Accuracy: 0.787, Val Accuracy: 0.935
# Epoch 8/100, Train Loss: 0.519, Val Loss: 0.488, Train Accuracy: 0.810, Val Accuracy: 0.935
# Epoch 9/100, Train Loss: 0.522, Val Loss: 0.482, Train Accuracy: 0.806, Val Accuracy: 0.935
# Epoch 10/100, Train Loss: 0.517, Val Loss: 0.482, Train Accuracy: 0.810, Val Accuracy: 0.935
# Epoch 11/100, Train Loss: 0.510, Val Loss: 0.455, Train Accuracy: 0.819, Val Accuracy: 0.935
# Epoch 12/100, Train Loss: 0.501, Val Loss: 0.446, Train Accuracy: 0.808, Val Accuracy: 0.935
# Epoch 13/100, Train Loss: 0.495, Val Loss: 0.446, Train Accuracy: 0.822, Val Accuracy: 0.935
# Epoch 14/100, Train Loss: 0.487, Val Loss: 0.440, Train Accuracy: 0.841, Val Accuracy: 0.935
# Epoch 15/100, Train Loss: 0.483, Val Loss: 0.436, Train Accuracy: 0.829, Val Accuracy: 0.935
# Epoch 16/100, Train Loss: 0.470, Val Loss: 0.411, Train Accuracy: 0.840, Val Accuracy: 0.935
# Epoch 17/100, Train Loss: 0.479, Val Loss: 0.394, Train Accuracy: 0.827, Val Accuracy: 0.935
# Epoch 18/100, Train Loss: 0.473, Val Loss: 0.404, Train Accuracy: 0.836, Val Accuracy: 0.935
# Epoch 19/100, Train Loss: 0.469, Val Loss: 0.392, Train Accuracy: 0.834, Val Accuracy: 0.935
# Epoch 20/100, Train Loss: 0.475, Val Loss: 0.367, Train Accuracy: 0.824, Val Accuracy: 0.935
# Epoch 21/100, Train Loss: 0.455, Val Loss: 0.386, Train Accuracy: 0.838, Val Accuracy: 0.935
# Epoch 22/100, Train Loss: 0.466, Val Loss: 0.383, Train Accuracy: 0.823, Val Accuracy: 0.935
# Epoch 23/100, Train Loss: 0.460, Val Loss: 0.377, Train Accuracy: 0.834, Val Accuracy: 0.935
# Epoch 24/100, Train Loss: 0.452, Val Loss: 0.376, Train Accuracy: 0.837, Val Accuracy: 0.935
# Epoch 25/100, Train Loss: 0.453, Val Loss: 0.366, Train Accuracy: 0.833, Val Accuracy: 0.935
# Epoch 26/100, Train Loss: 0.455, Val Loss: 0.354, Train Accuracy: 0.838, Val Accuracy: 0.935
# Epoch 27/100, Train Loss: 0.436, Val Loss: 0.382, Train Accuracy: 0.834, Val Accuracy: 0.913
# Epoch 28/100, Train Loss: 0.442, Val Loss: 0.346, Train Accuracy: 0.830, Val Accuracy: 0.935
# Epoch 29/100, Train Loss: 0.448, Val Loss: 0.346, Train Accuracy: 0.831, Val Accuracy: 0.935
# Epoch 30/100, Train Loss: 0.435, Val Loss: 0.357, Train Accuracy: 0.833, Val Accuracy: 0.935
# Epoch 31/100, Train Loss: 0.443, Val Loss: 0.348, Train Accuracy: 0.830, Val Accuracy: 0.935
# Epoch 32/100, Train Loss: 0.425, Val Loss: 0.368, Train Accuracy: 0.849, Val Accuracy: 0.913
# Epoch 33/100, Train Loss: 0.447, Val Loss: 0.356, Train Accuracy: 0.826, Val Accuracy: 0.913
# Epoch 34/100, Train Loss: 0.433, Val Loss: 0.333, Train Accuracy: 0.839, Val Accuracy: 0.935
# Epoch 35/100, Train Loss: 0.435, Val Loss: 0.332, Train Accuracy: 0.836, Val Accuracy: 0.935
# Epoch 36/100, Train Loss: 0.422, Val Loss: 0.343, Train Accuracy: 0.833, Val Accuracy: 0.935
# Epoch 37/100, Train Loss: 0.422, Val Loss: 0.317, Train Accuracy: 0.840, Val Accuracy: 0.935
# Epoch 38/100, Train Loss: 0.419, Val Loss: 0.327, Train Accuracy: 0.854, Val Accuracy: 0.935
# Epoch 39/100, Train Loss: 0.427, Val Loss: 0.349, Train Accuracy: 0.833, Val Accuracy: 0.891
# Epoch 40/100, Train Loss: 0.426, Val Loss: 0.324, Train Accuracy: 0.843, Val Accuracy: 0.935
# Epoch 41/100, Train Loss: 0.418, Val Loss: 0.328, Train Accuracy: 0.839, Val Accuracy: 0.935
# Epoch 42/100, Train Loss: 0.425, Val Loss: 0.351, Train Accuracy: 0.848, Val Accuracy: 0.935
# Epoch 43/100, Train Loss: 0.417, Val Loss: 0.375, Train Accuracy: 0.844, Val Accuracy: 0.891
# Epoch 44/100, Train Loss: 0.404, Val Loss: 0.348, Train Accuracy: 0.853, Val Accuracy: 0.913
# Epoch 45/100, Train Loss: 0.404, Val Loss: 0.388, Train Accuracy: 0.843, Val Accuracy: 0.870
# Epoch 46/100, Train Loss: 0.409, Val Loss: 0.360, Train Accuracy: 0.846, Val Accuracy: 0.913
# Epoch 47/100, Train Loss: 0.416, Val Loss: 0.316, Train Accuracy: 0.845, Val Accuracy: 0.935
# Early stopping
#
# Total Training Time: 11.87 seconds
# Test Loss: 0.494, Test Accuracy: 0.786
#
# Matthews Correlation Coefficient: 0.572
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.80      0.77      0.78        91
#          1.0       0.78      0.80      0.79        91
#
#     accuracy                           0.79       182
#    macro avg       0.79      0.79      0.79       182
# weighted avg       0.79      0.79      0.79       182
#
#
# Confusion Matrix:

# %%
device, model, criterion, optimizer = declare_model(model_llm='XLM-R', kernel_size=KERNEL_SIZE, learning_rate=LEARNING_RATE)
training(train_loader, val_loader, model, criterion, optimizer, device, epochs=EPOCH, patience=PATIENCE, min_delta=MIN_DELTA)
evaluate(test_loader, model, criterion, optimizer, device)
# Out:
# Training CNN with Embedding XLM-R
#
# CNN Architecture:
# CNNModel(
#   (embedding): Embedding(2521, 1024, padding_idx=0)
#   (layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#   (conv1): Conv1d(1024, 256, kernel_size=(3,), stride=(1,))
#   (bn1): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv2): Conv1d(256, 128, kernel_size=(3,), stride=(1,))
#   (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv3): Conv1d(128, 64, kernel_size=(3,), stride=(1,))
#   (bn3): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv4): Conv1d(64, 32, kernel_size=(3,), stride=(1,))
#   (bn4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (maxpool): MaxPool1d(kernel_size=3, stride=3, padding=0, dilation=1, ceil_mode=False)
#   (global_maxpool): AdaptiveMaxPool1d(output_size=1)
#   (dropout): Dropout(p=0.2, inplace=False)
#   (fc1): Linear(in_features=32, out_features=16, bias=True)
#   (fc2): Linear(in_features=16, out_features=1, bias=True)
#   (relu): ReLU()
# )
#
# Epoch 1/100, Train Loss: 0.676, Val Loss: 0.689, Train Accuracy: 0.510, Val Accuracy: 0.500
# Epoch 2/100, Train Loss: 0.641, Val Loss: 0.641, Train Accuracy: 0.585, Val Accuracy: 0.500
# Epoch 3/100, Train Loss: 0.600, Val Loss: 0.595, Train Accuracy: 0.657, Val Accuracy: 0.500
# Epoch 4/100, Train Loss: 0.592, Val Loss: 0.576, Train Accuracy: 0.667, Val Accuracy: 0.500
# Epoch 5/100, Train Loss: 0.580, Val Loss: 0.564, Train Accuracy: 0.696, Val Accuracy: 0.543
# Epoch 6/100, Train Loss: 0.570, Val Loss: 0.565, Train Accuracy: 0.724, Val Accuracy: 0.587
# Epoch 7/100, Train Loss: 0.555, Val Loss: 0.569, Train Accuracy: 0.750, Val Accuracy: 0.717
# Epoch 8/100, Train Loss: 0.551, Val Loss: 0.554, Train Accuracy: 0.762, Val Accuracy: 0.739
# Epoch 9/100, Train Loss: 0.535, Val Loss: 0.541, Train Accuracy: 0.769, Val Accuracy: 0.783
# Epoch 10/100, Train Loss: 0.515, Val Loss: 0.529, Train Accuracy: 0.799, Val Accuracy: 0.804
# Epoch 11/100, Train Loss: 0.510, Val Loss: 0.513, Train Accuracy: 0.815, Val Accuracy: 0.891
# Epoch 12/100, Train Loss: 0.500, Val Loss: 0.519, Train Accuracy: 0.825, Val Accuracy: 0.913
# Epoch 13/100, Train Loss: 0.491, Val Loss: 0.492, Train Accuracy: 0.825, Val Accuracy: 0.935
# Epoch 14/100, Train Loss: 0.476, Val Loss: 0.484, Train Accuracy: 0.844, Val Accuracy: 0.935
# Epoch 15/100, Train Loss: 0.460, Val Loss: 0.477, Train Accuracy: 0.865, Val Accuracy: 0.935
# Epoch 16/100, Train Loss: 0.451, Val Loss: 0.442, Train Accuracy: 0.873, Val Accuracy: 0.935
# Epoch 17/100, Train Loss: 0.431, Val Loss: 0.441, Train Accuracy: 0.885, Val Accuracy: 0.957
# Epoch 18/100, Train Loss: 0.423, Val Loss: 0.507, Train Accuracy: 0.887, Val Accuracy: 0.870
# Epoch 19/100, Train Loss: 0.401, Val Loss: 0.401, Train Accuracy: 0.905, Val Accuracy: 0.957
# Epoch 20/100, Train Loss: 0.388, Val Loss: 0.374, Train Accuracy: 0.911, Val Accuracy: 0.957
# Epoch 21/100, Train Loss: 0.376, Val Loss: 0.448, Train Accuracy: 0.929, Val Accuracy: 0.891
# Epoch 22/100, Train Loss: 0.358, Val Loss: 0.368, Train Accuracy: 0.916, Val Accuracy: 0.935
# Epoch 23/100, Train Loss: 0.341, Val Loss: 0.327, Train Accuracy: 0.921, Val Accuracy: 0.957
# Epoch 24/100, Train Loss: 0.341, Val Loss: 0.290, Train Accuracy: 0.932, Val Accuracy: 0.978
# Epoch 25/100, Train Loss: 0.322, Val Loss: 0.297, Train Accuracy: 0.933, Val Accuracy: 0.978
# Epoch 26/100, Train Loss: 0.312, Val Loss: 0.329, Train Accuracy: 0.940, Val Accuracy: 0.935
# Epoch 27/100, Train Loss: 0.320, Val Loss: 0.281, Train Accuracy: 0.924, Val Accuracy: 0.978
# Epoch 28/100, Train Loss: 0.277, Val Loss: 0.297, Train Accuracy: 0.946, Val Accuracy: 0.957
# Epoch 29/100, Train Loss: 0.267, Val Loss: 0.347, Train Accuracy: 0.956, Val Accuracy: 0.913
# Epoch 30/100, Train Loss: 0.254, Val Loss: 0.313, Train Accuracy: 0.956, Val Accuracy: 0.935
# Epoch 31/100, Train Loss: 0.244, Val Loss: 0.260, Train Accuracy: 0.956, Val Accuracy: 0.978
# Epoch 32/100, Train Loss: 0.235, Val Loss: 0.234, Train Accuracy: 0.956, Val Accuracy: 1.000
# Epoch 33/100, Train Loss: 0.228, Val Loss: 0.237, Train Accuracy: 0.964, Val Accuracy: 0.957
# Epoch 34/100, Train Loss: 0.218, Val Loss: 0.232, Train Accuracy: 0.972, Val Accuracy: 0.957
# Epoch 35/100, Train Loss: 0.209, Val Loss: 0.286, Train Accuracy: 0.967, Val Accuracy: 0.935
# Epoch 36/100, Train Loss: 0.202, Val Loss: 0.353, Train Accuracy: 0.971, Val Accuracy: 0.870
# Epoch 37/100, Train Loss: 0.197, Val Loss: 0.233, Train Accuracy: 0.963, Val Accuracy: 0.957
# Epoch 38/100, Train Loss: 0.189, Val Loss: 0.289, Train Accuracy: 0.963, Val Accuracy: 0.913
# Epoch 39/100, Train Loss: 0.196, Val Loss: 0.217, Train Accuracy: 0.975, Val Accuracy: 0.957
# Epoch 40/100, Train Loss: 0.182, Val Loss: 0.214, Train Accuracy: 0.976, Val Accuracy: 0.957
# Epoch 41/100, Train Loss: 0.173, Val Loss: 0.173, Train Accuracy: 0.971, Val Accuracy: 0.957
# Epoch 42/100, Train Loss: 0.163, Val Loss: 0.193, Train Accuracy: 0.978, Val Accuracy: 0.935
# Epoch 43/100, Train Loss: 0.151, Val Loss: 0.260, Train Accuracy: 0.980, Val Accuracy: 0.935
# Epoch 44/100, Train Loss: 0.151, Val Loss: 0.213, Train Accuracy: 0.983, Val Accuracy: 0.935
# Epoch 45/100, Train Loss: 0.150, Val Loss: 0.386, Train Accuracy: 0.980, Val Accuracy: 0.804
# Epoch 46/100, Train Loss: 0.142, Val Loss: 0.169, Train Accuracy: 0.980, Val Accuracy: 0.957
# Epoch 47/100, Train Loss: 0.133, Val Loss: 0.186, Train Accuracy: 0.983, Val Accuracy: 0.957
# Epoch 48/100, Train Loss: 0.130, Val Loss: 0.183, Train Accuracy: 0.982, Val Accuracy: 0.957
# Epoch 49/100, Train Loss: 0.134, Val Loss: 0.213, Train Accuracy: 0.985, Val Accuracy: 0.935
# Epoch 50/100, Train Loss: 0.119, Val Loss: 0.210, Train Accuracy: 0.991, Val Accuracy: 0.891
# Epoch 51/100, Train Loss: 0.112, Val Loss: 0.182, Train Accuracy: 0.992, Val Accuracy: 0.935
# Epoch 52/100, Train Loss: 0.120, Val Loss: 0.201, Train Accuracy: 0.982, Val Accuracy: 0.935
# Epoch 53/100, Train Loss: 0.116, Val Loss: 0.174, Train Accuracy: 0.987, Val Accuracy: 0.957
# Epoch 54/100, Train Loss: 0.116, Val Loss: 0.194, Train Accuracy: 0.983, Val Accuracy: 0.957
# Epoch 55/100, Train Loss: 0.110, Val Loss: 0.240, Train Accuracy: 0.992, Val Accuracy: 0.891
# Epoch 56/100, Train Loss: 0.105, Val Loss: 0.189, Train Accuracy: 0.993, Val Accuracy: 0.935
# Early stopping
#
# Total Training Time: 6.63 seconds
# Test Loss: 0.311, Test Accuracy: 0.871
#
# Matthews Correlation Coefficient: 0.753
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.83      0.93      0.88        91
#          1.0       0.93      0.81      0.87        91
#
#     accuracy                           0.87       182
#    macro avg       0.88      0.87      0.87       182
# weighted avg       0.88      0.87      0.87       182
#
#
# Confusion Matrix:

# %%
device, model, criterion, optimizer = declare_model(model_llm='mT5', kernel_size=KERNEL_SIZE, learning_rate=LEARNING_RATE)
training(train_loader, val_loader, model, criterion, optimizer, device, epochs=EPOCH, patience=PATIENCE, min_delta=MIN_DELTA)
evaluate(test_loader, model, criterion, optimizer, device)
# Out:
# Training CNN with Embedding mT5
#
# CNN Architecture:
# CNNModel(
#   (embedding): Embedding(2521, 1024, padding_idx=0)
#   (layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#   (conv1): Conv1d(1024, 256, kernel_size=(3,), stride=(1,))
#   (bn1): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv2): Conv1d(256, 128, kernel_size=(3,), stride=(1,))
#   (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv3): Conv1d(128, 64, kernel_size=(3,), stride=(1,))
#   (bn3): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv4): Conv1d(64, 32, kernel_size=(3,), stride=(1,))
#   (bn4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (maxpool): MaxPool1d(kernel_size=3, stride=3, padding=0, dilation=1, ceil_mode=False)
#   (global_maxpool): AdaptiveMaxPool1d(output_size=1)
#   (dropout): Dropout(p=0.2, inplace=False)
#   (fc1): Linear(in_features=32, out_features=16, bias=True)
#   (fc2): Linear(in_features=16, out_features=1, bias=True)
#   (relu): ReLU()
# )
#
# Epoch 1/100, Train Loss: 0.678, Val Loss: 0.676, Train Accuracy: 0.507, Val Accuracy: 0.500
# Epoch 2/100, Train Loss: 0.620, Val Loss: 0.609, Train Accuracy: 0.530, Val Accuracy: 0.500
# Epoch 3/100, Train Loss: 0.598, Val Loss: 0.563, Train Accuracy: 0.569, Val Accuracy: 0.500
# Epoch 4/100, Train Loss: 0.584, Val Loss: 0.556, Train Accuracy: 0.623, Val Accuracy: 0.500
# Epoch 5/100, Train Loss: 0.553, Val Loss: 0.535, Train Accuracy: 0.675, Val Accuracy: 0.522
# Epoch 6/100, Train Loss: 0.547, Val Loss: 0.515, Train Accuracy: 0.703, Val Accuracy: 0.609
# Epoch 7/100, Train Loss: 0.528, Val Loss: 0.488, Train Accuracy: 0.751, Val Accuracy: 0.696
# Epoch 8/100, Train Loss: 0.520, Val Loss: 0.471, Train Accuracy: 0.755, Val Accuracy: 0.804
# Epoch 9/100, Train Loss: 0.492, Val Loss: 0.457, Train Accuracy: 0.782, Val Accuracy: 0.848
# Epoch 10/100, Train Loss: 0.490, Val Loss: 0.461, Train Accuracy: 0.780, Val Accuracy: 0.935
# Epoch 11/100, Train Loss: 0.482, Val Loss: 0.441, Train Accuracy: 0.812, Val Accuracy: 0.978
# Epoch 12/100, Train Loss: 0.450, Val Loss: 0.426, Train Accuracy: 0.869, Val Accuracy: 1.000
# Epoch 13/100, Train Loss: 0.444, Val Loss: 0.449, Train Accuracy: 0.872, Val Accuracy: 1.000
# Epoch 14/100, Train Loss: 0.417, Val Loss: 0.394, Train Accuracy: 0.896, Val Accuracy: 0.957
# Epoch 15/100, Train Loss: 0.410, Val Loss: 0.377, Train Accuracy: 0.893, Val Accuracy: 1.000
# Epoch 16/100, Train Loss: 0.390, Val Loss: 0.365, Train Accuracy: 0.919, Val Accuracy: 1.000
# Epoch 17/100, Train Loss: 0.367, Val Loss: 0.349, Train Accuracy: 0.923, Val Accuracy: 1.000
# Epoch 18/100, Train Loss: 0.349, Val Loss: 0.344, Train Accuracy: 0.929, Val Accuracy: 1.000
# Epoch 19/100, Train Loss: 0.329, Val Loss: 0.329, Train Accuracy: 0.934, Val Accuracy: 1.000
# Epoch 20/100, Train Loss: 0.319, Val Loss: 0.321, Train Accuracy: 0.943, Val Accuracy: 1.000
# Epoch 21/100, Train Loss: 0.313, Val Loss: 0.303, Train Accuracy: 0.951, Val Accuracy: 1.000
# Epoch 22/100, Train Loss: 0.291, Val Loss: 0.299, Train Accuracy: 0.957, Val Accuracy: 0.978
# Epoch 23/100, Train Loss: 0.283, Val Loss: 0.289, Train Accuracy: 0.955, Val Accuracy: 0.957
# Epoch 24/100, Train Loss: 0.264, Val Loss: 0.268, Train Accuracy: 0.967, Val Accuracy: 1.000
# Epoch 25/100, Train Loss: 0.244, Val Loss: 0.283, Train Accuracy: 0.981, Val Accuracy: 0.935
# Epoch 26/100, Train Loss: 0.225, Val Loss: 0.249, Train Accuracy: 0.977, Val Accuracy: 1.000
# Epoch 27/100, Train Loss: 0.227, Val Loss: 0.240, Train Accuracy: 0.960, Val Accuracy: 0.957
# Epoch 28/100, Train Loss: 0.217, Val Loss: 0.218, Train Accuracy: 0.972, Val Accuracy: 0.978
# Epoch 29/100, Train Loss: 0.202, Val Loss: 0.258, Train Accuracy: 0.971, Val Accuracy: 0.957
# Epoch 30/100, Train Loss: 0.198, Val Loss: 0.275, Train Accuracy: 0.988, Val Accuracy: 0.935
# Epoch 31/100, Train Loss: 0.180, Val Loss: 0.207, Train Accuracy: 0.984, Val Accuracy: 0.957
# Epoch 32/100, Train Loss: 0.172, Val Loss: 0.196, Train Accuracy: 0.984, Val Accuracy: 1.000
# Epoch 33/100, Train Loss: 0.168, Val Loss: 0.230, Train Accuracy: 0.985, Val Accuracy: 0.957
# Epoch 34/100, Train Loss: 0.160, Val Loss: 0.193, Train Accuracy: 0.983, Val Accuracy: 0.978
# Epoch 35/100, Train Loss: 0.153, Val Loss: 0.231, Train Accuracy: 0.987, Val Accuracy: 0.957
# Epoch 36/100, Train Loss: 0.152, Val Loss: 0.259, Train Accuracy: 0.986, Val Accuracy: 0.913
# Epoch 37/100, Train Loss: 0.139, Val Loss: 0.213, Train Accuracy: 0.995, Val Accuracy: 0.957
# Epoch 38/100, Train Loss: 0.131, Val Loss: 0.210, Train Accuracy: 0.993, Val Accuracy: 0.957
# Epoch 39/100, Train Loss: 0.144, Val Loss: 0.268, Train Accuracy: 0.987, Val Accuracy: 0.913
# Epoch 40/100, Train Loss: 0.131, Val Loss: 0.272, Train Accuracy: 0.990, Val Accuracy: 0.913
# Epoch 41/100, Train Loss: 0.130, Val Loss: 0.175, Train Accuracy: 0.988, Val Accuracy: 0.935
# Epoch 42/100, Train Loss: 0.127, Val Loss: 0.175, Train Accuracy: 0.989, Val Accuracy: 0.957
# Epoch 43/100, Train Loss: 0.116, Val Loss: 0.237, Train Accuracy: 0.993, Val Accuracy: 0.913
# Epoch 44/100, Train Loss: 0.113, Val Loss: 0.231, Train Accuracy: 0.997, Val Accuracy: 0.913
# Epoch 45/100, Train Loss: 0.112, Val Loss: 0.200, Train Accuracy: 0.994, Val Accuracy: 0.957
# Epoch 46/100, Train Loss: 0.105, Val Loss: 0.196, Train Accuracy: 0.995, Val Accuracy: 0.957
# Epoch 47/100, Train Loss: 0.106, Val Loss: 0.184, Train Accuracy: 0.993, Val Accuracy: 0.957
# Epoch 48/100, Train Loss: 0.094, Val Loss: 0.214, Train Accuracy: 0.997, Val Accuracy: 0.957
# Epoch 49/100, Train Loss: 0.099, Val Loss: 0.200, Train Accuracy: 0.997, Val Accuracy: 0.957
# Epoch 50/100, Train Loss: 0.092, Val Loss: 0.207, Train Accuracy: 0.995, Val Accuracy: 0.935
# Epoch 51/100, Train Loss: 0.090, Val Loss: 0.188, Train Accuracy: 0.992, Val Accuracy: 0.957
# Early stopping
#
# Total Training Time: 4.84 seconds
# Test Loss: 0.205, Test Accuracy: 0.940
#
# Matthews Correlation Coefficient: 0.880
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.96      0.94        91
#          1.0       0.95      0.92      0.94        91
#
#     accuracy                           0.94       182
#    macro avg       0.94      0.94      0.94       182
# weighted avg       0.94      0.94      0.94       182
#
#
# Confusion Matrix:

# %%
device, model, criterion, optimizer = declare_model(model_llm='gpt2', kernel_size=KERNEL_SIZE, learning_rate=LEARNING_RATE)
training(train_loader, val_loader, model, criterion, optimizer, device, epochs=EPOCH, patience=PATIENCE, min_delta=MIN_DELTA)
evaluate(test_loader, model, criterion, optimizer, device)
# Out:
# Training CNN with Embedding gpt2
#
# CNN Architecture:
# CNNModel(
#   (embedding): Embedding(2521, 1024, padding_idx=0)
#   (layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#   (conv1): Conv1d(1024, 256, kernel_size=(3,), stride=(1,))
#   (bn1): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv2): Conv1d(256, 128, kernel_size=(3,), stride=(1,))
#   (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv3): Conv1d(128, 64, kernel_size=(3,), stride=(1,))
#   (bn3): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv4): Conv1d(64, 32, kernel_size=(3,), stride=(1,))
#   (bn4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (maxpool): MaxPool1d(kernel_size=3, stride=3, padding=0, dilation=1, ceil_mode=False)
#   (global_maxpool): AdaptiveMaxPool1d(output_size=1)
#   (dropout): Dropout(p=0.2, inplace=False)
#   (fc1): Linear(in_features=32, out_features=16, bias=True)
#   (fc2): Linear(in_features=16, out_features=1, bias=True)
#   (relu): ReLU()
# )
#
# Epoch 1/100, Train Loss: 0.683, Val Loss: 0.686, Train Accuracy: 0.576, Val Accuracy: 0.500
# Epoch 2/100, Train Loss: 0.645, Val Loss: 0.654, Train Accuracy: 0.714, Val Accuracy: 0.957
# Epoch 3/100, Train Loss: 0.624, Val Loss: 0.625, Train Accuracy: 0.749, Val Accuracy: 0.848
# Epoch 4/100, Train Loss: 0.614, Val Loss: 0.601, Train Accuracy: 0.759, Val Accuracy: 0.848
# Epoch 5/100, Train Loss: 0.598, Val Loss: 0.575, Train Accuracy: 0.769, Val Accuracy: 0.935
# Epoch 6/100, Train Loss: 0.585, Val Loss: 0.557, Train Accuracy: 0.788, Val Accuracy: 0.935
# Epoch 7/100, Train Loss: 0.574, Val Loss: 0.548, Train Accuracy: 0.794, Val Accuracy: 0.935
# Epoch 8/100, Train Loss: 0.566, Val Loss: 0.533, Train Accuracy: 0.804, Val Accuracy: 0.935
# Epoch 9/100, Train Loss: 0.553, Val Loss: 0.533, Train Accuracy: 0.806, Val Accuracy: 0.935
# Epoch 10/100, Train Loss: 0.544, Val Loss: 0.525, Train Accuracy: 0.817, Val Accuracy: 0.935
# Epoch 11/100, Train Loss: 0.529, Val Loss: 0.515, Train Accuracy: 0.837, Val Accuracy: 0.935
# Epoch 12/100, Train Loss: 0.524, Val Loss: 0.482, Train Accuracy: 0.834, Val Accuracy: 0.935
# Epoch 13/100, Train Loss: 0.513, Val Loss: 0.468, Train Accuracy: 0.835, Val Accuracy: 0.935
# Epoch 14/100, Train Loss: 0.512, Val Loss: 0.489, Train Accuracy: 0.839, Val Accuracy: 0.957
# Epoch 15/100, Train Loss: 0.502, Val Loss: 0.492, Train Accuracy: 0.840, Val Accuracy: 0.957
# Epoch 16/100, Train Loss: 0.481, Val Loss: 0.398, Train Accuracy: 0.850, Val Accuracy: 0.957
# Epoch 17/100, Train Loss: 0.469, Val Loss: 0.481, Train Accuracy: 0.860, Val Accuracy: 0.913
# Epoch 18/100, Train Loss: 0.461, Val Loss: 0.411, Train Accuracy: 0.866, Val Accuracy: 0.978
# Epoch 19/100, Train Loss: 0.444, Val Loss: 0.408, Train Accuracy: 0.882, Val Accuracy: 0.978
# Epoch 20/100, Train Loss: 0.420, Val Loss: 0.363, Train Accuracy: 0.896, Val Accuracy: 1.000
# Epoch 21/100, Train Loss: 0.412, Val Loss: 0.336, Train Accuracy: 0.908, Val Accuracy: 1.000
# Epoch 22/100, Train Loss: 0.391, Val Loss: 0.363, Train Accuracy: 0.915, Val Accuracy: 1.000
# Epoch 23/100, Train Loss: 0.381, Val Loss: 0.393, Train Accuracy: 0.920, Val Accuracy: 0.935
# Epoch 24/100, Train Loss: 0.369, Val Loss: 0.311, Train Accuracy: 0.909, Val Accuracy: 1.000
# Epoch 25/100, Train Loss: 0.370, Val Loss: 0.405, Train Accuracy: 0.920, Val Accuracy: 0.913
# Epoch 26/100, Train Loss: 0.345, Val Loss: 0.354, Train Accuracy: 0.930, Val Accuracy: 0.957
# Epoch 27/100, Train Loss: 0.344, Val Loss: 0.289, Train Accuracy: 0.914, Val Accuracy: 0.978
# Epoch 28/100, Train Loss: 0.331, Val Loss: 0.297, Train Accuracy: 0.940, Val Accuracy: 0.978
# Epoch 29/100, Train Loss: 0.310, Val Loss: 0.266, Train Accuracy: 0.932, Val Accuracy: 1.000
# Epoch 30/100, Train Loss: 0.300, Val Loss: 0.245, Train Accuracy: 0.948, Val Accuracy: 1.000
# Epoch 31/100, Train Loss: 0.289, Val Loss: 0.488, Train Accuracy: 0.945, Val Accuracy: 0.761
# Epoch 32/100, Train Loss: 0.283, Val Loss: 0.272, Train Accuracy: 0.949, Val Accuracy: 0.978
# Epoch 33/100, Train Loss: 0.271, Val Loss: 0.203, Train Accuracy: 0.953, Val Accuracy: 1.000
# Epoch 34/100, Train Loss: 0.259, Val Loss: 0.201, Train Accuracy: 0.963, Val Accuracy: 0.978
# Epoch 35/100, Train Loss: 0.246, Val Loss: 0.279, Train Accuracy: 0.967, Val Accuracy: 0.935
# Epoch 36/100, Train Loss: 0.251, Val Loss: 0.207, Train Accuracy: 0.964, Val Accuracy: 1.000
# Epoch 37/100, Train Loss: 0.238, Val Loss: 0.187, Train Accuracy: 0.962, Val Accuracy: 0.978
# Epoch 38/100, Train Loss: 0.227, Val Loss: 0.193, Train Accuracy: 0.971, Val Accuracy: 0.978
# Epoch 39/100, Train Loss: 0.220, Val Loss: 0.172, Train Accuracy: 0.970, Val Accuracy: 1.000
# Epoch 40/100, Train Loss: 0.208, Val Loss: 0.167, Train Accuracy: 0.972, Val Accuracy: 0.978
# Epoch 41/100, Train Loss: 0.204, Val Loss: 0.267, Train Accuracy: 0.972, Val Accuracy: 0.935
# Epoch 42/100, Train Loss: 0.192, Val Loss: 0.181, Train Accuracy: 0.975, Val Accuracy: 0.978
# Epoch 43/100, Train Loss: 0.211, Val Loss: 0.294, Train Accuracy: 0.972, Val Accuracy: 0.913
# Epoch 44/100, Train Loss: 0.203, Val Loss: 0.274, Train Accuracy: 0.963, Val Accuracy: 0.935
# Epoch 45/100, Train Loss: 0.186, Val Loss: 0.194, Train Accuracy: 0.970, Val Accuracy: 0.978
# Epoch 46/100, Train Loss: 0.174, Val Loss: 0.134, Train Accuracy: 0.981, Val Accuracy: 1.000
# Epoch 47/100, Train Loss: 0.166, Val Loss: 0.148, Train Accuracy: 0.980, Val Accuracy: 1.000
# Epoch 48/100, Train Loss: 0.166, Val Loss: 0.159, Train Accuracy: 0.985, Val Accuracy: 0.957
# Epoch 49/100, Train Loss: 0.157, Val Loss: 0.132, Train Accuracy: 0.984, Val Accuracy: 1.000
# Epoch 50/100, Train Loss: 0.144, Val Loss: 0.214, Train Accuracy: 0.992, Val Accuracy: 0.957
# Epoch 51/100, Train Loss: 0.144, Val Loss: 0.234, Train Accuracy: 0.988, Val Accuracy: 0.935
# Epoch 52/100, Train Loss: 0.159, Val Loss: 0.136, Train Accuracy: 0.980, Val Accuracy: 0.957
# Epoch 53/100, Train Loss: 0.156, Val Loss: 0.121, Train Accuracy: 0.986, Val Accuracy: 1.000
# Epoch 54/100, Train Loss: 0.146, Val Loss: 0.130, Train Accuracy: 0.985, Val Accuracy: 1.000
# Epoch 55/100, Train Loss: 0.140, Val Loss: 0.129, Train Accuracy: 0.984, Val Accuracy: 1.000
# Epoch 56/100, Train Loss: 0.134, Val Loss: 0.115, Train Accuracy: 0.990, Val Accuracy: 1.000
# Epoch 57/100, Train Loss: 0.126, Val Loss: 0.106, Train Accuracy: 0.992, Val Accuracy: 1.000
# Epoch 58/100, Train Loss: 0.122, Val Loss: 0.155, Train Accuracy: 0.988, Val Accuracy: 0.957
# Epoch 59/100, Train Loss: 0.127, Val Loss: 0.158, Train Accuracy: 0.986, Val Accuracy: 0.957
# Epoch 60/100, Train Loss: 0.117, Val Loss: 0.094, Train Accuracy: 0.995, Val Accuracy: 1.000
# Epoch 61/100, Train Loss: 0.117, Val Loss: 0.121, Train Accuracy: 0.990, Val Accuracy: 0.978
# Epoch 62/100, Train Loss: 0.113, Val Loss: 0.100, Train Accuracy: 0.990, Val Accuracy: 1.000
# Epoch 63/100, Train Loss: 0.109, Val Loss: 0.107, Train Accuracy: 0.995, Val Accuracy: 1.000
# Epoch 64/100, Train Loss: 0.108, Val Loss: 0.159, Train Accuracy: 0.994, Val Accuracy: 0.957
# Epoch 65/100, Train Loss: 0.105, Val Loss: 0.155, Train Accuracy: 0.998, Val Accuracy: 0.957
# Epoch 66/100, Train Loss: 0.105, Val Loss: 0.127, Train Accuracy: 0.996, Val Accuracy: 0.957
# Epoch 67/100, Train Loss: 0.095, Val Loss: 0.105, Train Accuracy: 0.993, Val Accuracy: 0.957
# Epoch 68/100, Train Loss: 0.099, Val Loss: 0.090, Train Accuracy: 0.994, Val Accuracy: 1.000
# Epoch 69/100, Train Loss: 0.100, Val Loss: 0.090, Train Accuracy: 0.996, Val Accuracy: 0.978
# Epoch 70/100, Train Loss: 0.099, Val Loss: 0.128, Train Accuracy: 0.992, Val Accuracy: 0.957
# Epoch 71/100, Train Loss: 0.095, Val Loss: 0.194, Train Accuracy: 0.997, Val Accuracy: 0.935
# Epoch 72/100, Train Loss: 0.090, Val Loss: 0.090, Train Accuracy: 0.998, Val Accuracy: 1.000
# Epoch 73/100, Train Loss: 0.092, Val Loss: 0.099, Train Accuracy: 0.992, Val Accuracy: 0.978
# Epoch 74/100, Train Loss: 0.092, Val Loss: 0.191, Train Accuracy: 0.994, Val Accuracy: 0.935
# Epoch 75/100, Train Loss: 0.092, Val Loss: 0.108, Train Accuracy: 0.993, Val Accuracy: 0.957
# Epoch 76/100, Train Loss: 0.090, Val Loss: 0.120, Train Accuracy: 0.997, Val Accuracy: 0.957
# Epoch 77/100, Train Loss: 0.084, Val Loss: 0.096, Train Accuracy: 0.999, Val Accuracy: 0.978
# Epoch 78/100, Train Loss: 0.080, Val Loss: 0.110, Train Accuracy: 0.997, Val Accuracy: 0.957
# Early stopping
#
# Total Training Time: 6.94 seconds
# Test Loss: 0.221, Test Accuracy: 0.935
#
# Matthews Correlation Coefficient: 0.880
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.97      0.94        91
#          1.0       0.97      0.91      0.94        91
#
#     accuracy                           0.94       182
#    macro avg       0.94      0.94      0.94       182
# weighted avg       0.94      0.94      0.94       182
#
#
# Confusion Matrix:

# %%
device, model, criterion, optimizer = declare_model(model_llm='llama2', kernel_size=KERNEL_SIZE, learning_rate=LEARNING_RATE)
training(train_loader, val_loader, model, criterion, optimizer, device, epochs=EPOCH, patience=PATIENCE, min_delta=MIN_DELTA)
evaluate(test_loader, model, criterion, optimizer, device)
# Out:
# Training CNN with Embedding llama2
#
# CNN Architecture:
# CNNModel(
#   (embedding): Embedding(2521, 4096, padding_idx=0)
#   (layer_norm): LayerNorm((4096,), eps=1e-05, elementwise_affine=True)
#   (conv1): Conv1d(4096, 256, kernel_size=(3,), stride=(1,))
#   (bn1): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv2): Conv1d(256, 128, kernel_size=(3,), stride=(1,))
#   (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv3): Conv1d(128, 64, kernel_size=(3,), stride=(1,))
#   (bn3): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv4): Conv1d(64, 32, kernel_size=(3,), stride=(1,))
#   (bn4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (maxpool): MaxPool1d(kernel_size=3, stride=3, padding=0, dilation=1, ceil_mode=False)
#   (global_maxpool): AdaptiveMaxPool1d(output_size=1)
#   (dropout): Dropout(p=0.2, inplace=False)
#   (fc1): Linear(in_features=32, out_features=16, bias=True)
#   (fc2): Linear(in_features=16, out_features=1, bias=True)
#   (relu): ReLU()
# )
#
# Epoch 1/100, Train Loss: 0.644, Val Loss: 0.671, Train Accuracy: 0.549, Val Accuracy: 0.500
# Epoch 2/100, Train Loss: 0.599, Val Loss: 0.592, Train Accuracy: 0.663, Val Accuracy: 0.696
# Epoch 3/100, Train Loss: 0.566, Val Loss: 0.542, Train Accuracy: 0.720, Val Accuracy: 0.848
# Epoch 4/100, Train Loss: 0.559, Val Loss: 0.531, Train Accuracy: 0.767, Val Accuracy: 0.891
# Epoch 5/100, Train Loss: 0.539, Val Loss: 0.509, Train Accuracy: 0.796, Val Accuracy: 0.913
# Epoch 6/100, Train Loss: 0.524, Val Loss: 0.501, Train Accuracy: 0.810, Val Accuracy: 0.913
# Epoch 7/100, Train Loss: 0.502, Val Loss: 0.478, Train Accuracy: 0.828, Val Accuracy: 0.935
# Epoch 8/100, Train Loss: 0.489, Val Loss: 0.485, Train Accuracy: 0.843, Val Accuracy: 0.957
# Epoch 9/100, Train Loss: 0.461, Val Loss: 0.509, Train Accuracy: 0.878, Val Accuracy: 0.913
# Epoch 10/100, Train Loss: 0.455, Val Loss: 0.432, Train Accuracy: 0.881, Val Accuracy: 0.957
# Epoch 11/100, Train Loss: 0.429, Val Loss: 0.409, Train Accuracy: 0.911, Val Accuracy: 0.957
# Epoch 12/100, Train Loss: 0.413, Val Loss: 0.480, Train Accuracy: 0.905, Val Accuracy: 0.913
# Epoch 13/100, Train Loss: 0.388, Val Loss: 0.436, Train Accuracy: 0.938, Val Accuracy: 0.957
# Epoch 14/100, Train Loss: 0.369, Val Loss: 0.383, Train Accuracy: 0.946, Val Accuracy: 1.000
# Epoch 15/100, Train Loss: 0.359, Val Loss: 0.370, Train Accuracy: 0.954, Val Accuracy: 0.978
# Epoch 16/100, Train Loss: 0.327, Val Loss: 0.372, Train Accuracy: 0.959, Val Accuracy: 1.000
# Epoch 17/100, Train Loss: 0.320, Val Loss: 0.373, Train Accuracy: 0.961, Val Accuracy: 0.957
# Epoch 18/100, Train Loss: 0.303, Val Loss: 0.363, Train Accuracy: 0.967, Val Accuracy: 0.935
# Epoch 19/100, Train Loss: 0.280, Val Loss: 0.318, Train Accuracy: 0.984, Val Accuracy: 0.957
# Epoch 20/100, Train Loss: 0.256, Val Loss: 0.308, Train Accuracy: 0.986, Val Accuracy: 0.957
# Epoch 21/100, Train Loss: 0.245, Val Loss: 0.287, Train Accuracy: 0.981, Val Accuracy: 0.957
# Epoch 22/100, Train Loss: 0.237, Val Loss: 0.262, Train Accuracy: 0.988, Val Accuracy: 0.957
# Epoch 23/100, Train Loss: 0.228, Val Loss: 0.285, Train Accuracy: 0.982, Val Accuracy: 0.957
# Epoch 24/100, Train Loss: 0.214, Val Loss: 0.255, Train Accuracy: 0.984, Val Accuracy: 0.978
# Epoch 25/100, Train Loss: 0.193, Val Loss: 0.332, Train Accuracy: 0.995, Val Accuracy: 0.913
# Epoch 26/100, Train Loss: 0.177, Val Loss: 0.290, Train Accuracy: 0.996, Val Accuracy: 0.891
# Epoch 27/100, Train Loss: 0.178, Val Loss: 0.288, Train Accuracy: 0.994, Val Accuracy: 0.935
# Epoch 28/100, Train Loss: 0.166, Val Loss: 0.227, Train Accuracy: 0.996, Val Accuracy: 0.957
# Epoch 29/100, Train Loss: 0.159, Val Loss: 0.229, Train Accuracy: 0.993, Val Accuracy: 0.935
# Epoch 30/100, Train Loss: 0.144, Val Loss: 0.209, Train Accuracy: 0.997, Val Accuracy: 0.978
# Epoch 31/100, Train Loss: 0.139, Val Loss: 0.208, Train Accuracy: 0.998, Val Accuracy: 0.978
# Epoch 32/100, Train Loss: 0.135, Val Loss: 0.277, Train Accuracy: 0.999, Val Accuracy: 0.913
# Epoch 33/100, Train Loss: 0.131, Val Loss: 0.234, Train Accuracy: 0.996, Val Accuracy: 0.935
# Epoch 34/100, Train Loss: 0.117, Val Loss: 0.246, Train Accuracy: 0.999, Val Accuracy: 0.913
# Epoch 35/100, Train Loss: 0.109, Val Loss: 0.196, Train Accuracy: 0.997, Val Accuracy: 0.957
# Epoch 36/100, Train Loss: 0.105, Val Loss: 0.197, Train Accuracy: 0.998, Val Accuracy: 0.935
# Epoch 37/100, Train Loss: 0.109, Val Loss: 0.304, Train Accuracy: 0.999, Val Accuracy: 0.891
# Epoch 38/100, Train Loss: 0.098, Val Loss: 0.388, Train Accuracy: 0.994, Val Accuracy: 0.870
# Epoch 39/100, Train Loss: 0.091, Val Loss: 0.274, Train Accuracy: 0.998, Val Accuracy: 0.891
# Epoch 40/100, Train Loss: 0.092, Val Loss: 0.268, Train Accuracy: 0.997, Val Accuracy: 0.891
# Epoch 41/100, Train Loss: 0.090, Val Loss: 0.398, Train Accuracy: 0.999, Val Accuracy: 0.848
# Epoch 42/100, Train Loss: 0.096, Val Loss: 0.208, Train Accuracy: 0.997, Val Accuracy: 0.913
# Epoch 43/100, Train Loss: 0.093, Val Loss: 0.330, Train Accuracy: 0.998, Val Accuracy: 0.848
# Epoch 44/100, Train Loss: 0.082, Val Loss: 0.359, Train Accuracy: 0.999, Val Accuracy: 0.848
# Epoch 45/100, Train Loss: 0.080, Val Loss: 0.224, Train Accuracy: 0.998, Val Accuracy: 0.891
# Early stopping
#
# Total Training Time: 3.83 seconds
# Test Loss: 0.252, Test Accuracy: 0.892
#
# Matthews Correlation Coefficient: 0.802
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.84      0.98      0.90        91
#          1.0       0.97      0.81      0.89        91
#
#     accuracy                           0.90       182
#    macro avg       0.91      0.90      0.89       182
# weighted avg       0.91      0.90      0.89       182
#
#
# Confusion Matrix:
